# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
import time
import pandas as pd

# %%
def init_browser():
    executable_path = {"executable_path": "chromedriver"}
    return Browser("chrome", **executable_path, headless=False)

# %% [markdown]
# ## Scrape Links

# %%
browser = init_browser()

#set url
url = "https://nodata.tv/blog"
browser.visit(url)

time.sleep(1)

#scrape page into Soup
html = browser.html
soup = bs(html, "html.parser")

# %%
project_box = soup.find("article", class_="project-box")

latestLink = project_box.find("a", class_="title")["href"]
print(latestLink)
# Out:
# https://nodata.tv/167726

# %%
links = []
for i in range(1, 2):
    boxes = soup.find_all("article", class_="project-box")

    for box in boxes:
        link = box.find("a", class_="title")["href"]
        links.append(link)
#     print(links)
    i += 1
    url = f"https://nodata.tv/blog/page/{i}"
    browser.visit(url)
    time.sleep(3)
    #scrape page into soup
    html = browser.html
    soup = bs(html, "html.parser")
print(links)
# Out:
# ['https://nodata.tv/167726', 'https://nodata.tv/167852', 'https://nodata.tv/167716', 'https://nodata.tv/167706', 'https://nodata.tv/167840', 'https://nodata.tv/167815', 'https://nodata.tv/167838', 'https://nodata.tv/167813', 'https://nodata.tv/167842', 'https://nodata.tv/167714', 'https://nodata.tv/167712', 'https://nodata.tv/167702', 'https://nodata.tv/167809', 'https://nodata.tv/167704', 'https://nodata.tv/167805', 'https://nodata.tv/167530', 'https://nodata.tv/167728', 'https://nodata.tv/167698', 'https://nodata.tv/167724', 'https://nodata.tv/167678', 'https://nodata.tv/167696', 'https://nodata.tv/167722', 'https://nodata.tv/167692', 'https://nodata.tv/167720', 'https://nodata.tv/167686', 'https://nodata.tv/167694', 'https://nodata.tv/167718', 'https://nodata.tv/167682', 'https://nodata.tv/167710', 'https://nodata.tv/167619', 'https://nodata.tv/167708', 'https://nodata.tv/167625', 'https://nodata.tv/167700', 'https://nodata.tv/167615', 'https://nodata.tv/167508', 'https://nodata.tv/167688', 'https://nodata.tv/167611', 'https://nodata.tv/167684', 'https://nodata.tv/167609', 'https://nodata.tv/167690']

# %% [markdown]
# ## Scrape Album Info

# %%
undergroundMusic = []
for link in links:
    browser.visit(link)

    time.sleep(3)

    #scrape page into Soup
    html = browser.html
    soup = bs(html, "html.parser")
    
    #find main div
    main = soup.find("div", {"id": "main"})
    
    #find artist, album, year
    title = main.find("h4").text
    artist = title.split("/")[0]
    album = title.split("/ ")[1].split("[")[0]
    year = title.split("[")[1].split("]")[0]
    print(artist, album, year)
    
    #find genre tags in metadata
    metadata = main.find("ul", class_="meta")
    date = metadata.find_all("li")[1].text
    tags = metadata.find_all("li")[2]
    tags = tags.find_all("a")
    #add tags to genres list
    genres = []
    for tag in tags:
        genre = tag.text
        genres.append(genre)
    print(date)
    print(genres)
    
    #find cover img url
    cover_link = main.find("img")["src"]
    print(cover_link)
    
    #find label and catalog number
    label = main.find("section", class_="post").text
    split = label.split("[")
    labeldata = split[1].split("]")[0]
    label = labeldata.split(": ")[1].split(" |")[0]
    catalog = labeldata.split(": ")[2]
    print(label, catalog)

    #compile album info into dict
    albumInfo = {
        "url": link,
        "artist": artist,
        "album": album,
        "year": year,
        "date": date,
        "genres": genres,
        "cover": cover_link,
        "label": label,
        "catalog": catalog
    }
    print(albumInfo)
    
    #add dict to underground music list
    undergroundMusic.append(albumInfo)
# Out:
# Antoni Maiovvi  The Ken Russell  2018
# Jan 30, 2019
# ['Electronic', 'EP', 'Techno']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12858214.jpg
# OMNIDISC OMD019
# {'url': 'https://nodata.tv/167726', 'artist': 'Antoni Maiovvi ', 'album': 'The Ken Russell ', 'year': '2018', 'date': 'Jan 30, 2019', 'genres': ['Electronic', 'EP', 'Techno'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12858214.jpg', 'label': 'OMNIDISC', 'catalog': 'OMD019'}
# Substance  Rise and Shine  2019
# Jan 30, 2019
# ['Electronic', 'EP', 'Experimental', 'Techno']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13085086.jpg
# Ostgut Ton OTON115
# {'url': 'https://nodata.tv/167852', 'artist': 'Substance ', 'album': 'Rise and Shine ', 'year': '2019', 'date': 'Jan 30, 2019', 'genres': ['Electronic', 'EP', 'Experimental', 'Techno'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13085086.jpg', 'label': 'Ostgut Ton', 'catalog': 'OTON115'}
# Andrés  D.ATLien  2018
# Jan 30, 2019
# ['Electronic', 'EP', 'Funk', 'Hip Hop', 'House', 'Soul', 'World']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12765999.jpg
# NDATL NDATL021
# {'url': 'https://nodata.tv/167716', 'artist': 'Andrés ', 'album': 'D.ATLien ', 'year': '2018', 'date': 'Jan 30, 2019', 'genres': ['Electronic', 'EP', 'Funk', 'Hip Hop', 'House', 'Soul', 'World'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12765999.jpg', 'label': 'NDATL', 'catalog': 'NDATL021'}
# Golpe De Estado  Liquido  2019
# Jan 30, 2019
# ['Disco', 'Electronic', 'House', 'Single']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-10105957.jpg
# Discos Capablanca DISCODIECISEIS
# {'url': 'https://nodata.tv/167706', 'artist': 'Golpe De Estado ', 'album': 'Liquido ', 'year': '2019', 'date': 'Jan 30, 2019', 'genres': ['Disco', 'Electronic', 'House', 'Single'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-10105957.jpg', 'label': 'Discos Capablanca', 'catalog': 'DISCODIECISEIS'}
# JH1.FS3  Trials and Tribulations  2019
# Jan 30, 2019
# ['Album', 'Ambient', 'Electronic', 'Experimental', 'Industrial']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13139086.jpg
# Dais DAIS126
# {'url': 'https://nodata.tv/167840', 'artist': 'JH1.FS3 ', 'album': 'Trials and Tribulations ', 'year': '2019', 'date': 'Jan 30, 2019', 'genres': ['Album', 'Ambient', 'Electronic', 'Experimental', 'Industrial'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13139086.jpg', 'label': 'Dais', 'catalog': 'DAIS126'}
# Various Artists  Jazz Is The Teacher – Funk Is The Preacher  2018
# Jan 30, 2019
# ['Compilation', 'Funk', 'Jazz', 'Soul', 'Various Artists']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12846202.jpg
# Soul Jazz SJR423
# {'url': 'https://nodata.tv/167815', 'artist': 'Various Artists ', 'album': 'Jazz Is The Teacher – Funk Is The Preacher ', 'year': '2018', 'date': 'Jan 30, 2019', 'genres': ['Compilation', 'Funk', 'Jazz', 'Soul', 'Various Artists'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12846202.jpg', 'label': 'Soul Jazz', 'catalog': 'SJR423'}
# Free Level  Blue Grass  2019
# Jan 30, 2019
# ['Electronic', 'EP', 'New Wave', 'Synth-pop']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13047491.jpg
# Into The Light ITL009
# {'url': 'https://nodata.tv/167838', 'artist': 'Free Level ', 'album': 'Blue Grass ', 'year': '2019', 'date': 'Jan 30, 2019', 'genres': ['Electronic', 'EP', 'New Wave', 'Synth-pop'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13047491.jpg', 'label': 'Into The Light', 'catalog': 'ITL009'}
# Martina Lussi  Diffusion Is a Force  2019
# Jan 30, 2019
# ['Abstract', 'Album', 'Ambient', 'Electronic']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13139866.jpg
# Latency LTNC016
# {'url': 'https://nodata.tv/167813', 'artist': 'Martina Lussi ', 'album': 'Diffusion Is a Force ', 'year': '2019', 'date': 'Jan 30, 2019', 'genres': ['Abstract', 'Album', 'Ambient', 'Electronic'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13139866.jpg', 'label': 'Latency', 'catalog': 'LTNC016'}
# Various Artists  Black Label Series 03  2019
# Jan 30, 2019
# ['Breaks', 'Drum n Bass', 'Electronic', 'EP', 'House', 'Leftfield', 'Minimal', 'Various Artists']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-8205088.jpg
# Banoffee Pies BPBL03
# {'url': 'https://nodata.tv/167842', 'artist': 'Various Artists ', 'album': 'Black Label Series 03 ', 'year': '2019', 'date': 'Jan 30, 2019', 'genres': ['Breaks', 'Drum n Bass', 'Electronic', 'EP', 'House', 'Leftfield', 'Minimal', 'Various Artists'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-8205088.jpg', 'label': 'Banoffee Pies', 'catalog': 'BPBL03'}
# Unknown Artist  WASH#2  2018
# Jan 30, 2019
# ['Disco', 'Electronic', 'EP']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12420904.jpg
# Delicate Wash WASH#2
# {'url': 'https://nodata.tv/167714', 'artist': 'Unknown Artist ', 'album': 'WASH#2 ', 'year': '2018', 'date': 'Jan 30, 2019', 'genres': ['Disco', 'Electronic', 'EP'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12420904.jpg', 'label': 'Delicate Wash', 'catalog': 'WASH#2'}
# De Gama  Funktastic  2018
# Jan 28, 2019
# ['Disco', 'Electronic', 'EP', 'Funk', 'House', 'Soul']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-11908298.jpg
# Samosa SMS004
# {'url': 'https://nodata.tv/167712', 'artist': 'De Gama ', 'album': 'Funktastic ', 'year': '2018', 'date': 'Jan 28, 2019', 'genres': ['Disco', 'Electronic', 'EP', 'Funk', 'House', 'Soul'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-11908298.jpg', 'label': 'Samosa', 'catalog': 'SMS004'}
# Coppice Halifax  Etchings In Rust  2018
# Jan 28, 2019
# ['Album', 'Ambient', 'Electronic', 'Techno']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-9656437.jpg
# Self-released none
# {'url': 'https://nodata.tv/167702', 'artist': 'Coppice Halifax ', 'album': 'Etchings In Rust ', 'year': '2018', 'date': 'Jan 28, 2019', 'genres': ['Album', 'Ambient', 'Electronic', 'Techno'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-9656437.jpg', 'label': 'Self-released', 'catalog': 'none'}
# Pablo’s Eye  Dark Matter  2019
# Jan 28, 2019
# ['Ambient', 'Electronic', 'Experimental']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12855550.jpg
# STROOM  STRLP022
# {'url': 'https://nodata.tv/167809', 'artist': 'Pablo’s Eye ', 'album': 'Dark Matter ', 'year': '2019', 'date': 'Jan 28, 2019', 'genres': ['Ambient', 'Electronic', 'Experimental'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12855550.jpg', 'label': 'STROOM ', 'catalog': 'STRLP022'}
# German Army  MOVE9  2018
# Jan 28, 2019
# ['Album', 'Electronic', 'Experimental']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13021642.jpg
# Fort Evil Fruit FEF74
# {'url': 'https://nodata.tv/167704', 'artist': 'German Army ', 'album': 'MOVE9 ', 'year': '2018', 'date': 'Jan 28, 2019', 'genres': ['Album', 'Electronic', 'Experimental'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13021642.jpg', 'label': 'Fort Evil Fruit', 'catalog': 'FEF74'}
# Jigga  iliiiilii  2019
# Jan 28, 2019
# ['Ambient', 'Club', 'Drone', 'Dub', 'Electronic', 'EP', 'Experimental', 'Industrial', 'Leftfield', 'Shoegaze', 'Techno']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13043829.jpg
# Bedouin BDN022
# {'url': 'https://nodata.tv/167805', 'artist': 'Jigga ', 'album': 'iliiiilii ', 'year': '2019', 'date': 'Jan 28, 2019', 'genres': ['Ambient', 'Club', 'Drone', 'Dub', 'Electronic', 'EP', 'Experimental', 'Industrial', 'Leftfield', 'Shoegaze', 'Techno'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13043829.jpg', 'label': 'Bedouin', 'catalog': 'BDN022'}
# Ami Shavit  Yom Kippur 1973  2019
# Jan 28, 2019
# ['Abstract', 'Album', 'Ambient', 'Electronic', 'Experimental', 'Synth Wave']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13095501.jpg
# Sub Rosa SRV456
# {'url': 'https://nodata.tv/167530', 'artist': 'Ami Shavit ', 'album': 'Yom Kippur 1973 ', 'year': '2019', 'date': 'Jan 28, 2019', 'genres': ['Abstract', 'Album', 'Ambient', 'Electronic', 'Experimental', 'Synth Wave'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13095501.jpg', 'label': 'Sub Rosa', 'catalog': 'SRV456'}
# Jay Glass Dubs  Epitaph  2019
# Jan 28, 2019
# ['Album', 'Dub', 'Electronic', 'Experimental', 'Industrial', 'Leftfield']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13078300.jpg
# Bokeh Versions BKV023
# {'url': 'https://nodata.tv/167728', 'artist': 'Jay Glass Dubs ', 'album': 'Epitaph ', 'year': '2019', 'date': 'Jan 28, 2019', 'genres': ['Album', 'Dub', 'Electronic', 'Experimental', 'Industrial', 'Leftfield'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13078300.jpg', 'label': 'Bokeh Versions', 'catalog': 'BKV023'}
# Various Artists  Casa Sports Vol.2  2018
# Jan 28, 2019
# ['Electronic', 'EP', 'House', 'Techno', 'Various Artists']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12713202.jpg
# Casa Voyager CSV04
# {'url': 'https://nodata.tv/167698', 'artist': 'Various Artists ', 'album': 'Casa Sports Vol.2 ', 'year': '2018', 'date': 'Jan 28, 2019', 'genres': ['Electronic', 'EP', 'House', 'Techno', 'Various Artists'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12713202.jpg', 'label': 'Casa Voyager', 'catalog': 'CSV04'}
# Cassettes For Kids & Tom Jarmey  UNIT01  2019
# Jan 27, 2019
# ['Electronic', 'EP', 'House']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-9617904.jpg
# Unit Two UNIT01
# {'url': 'https://nodata.tv/167724', 'artist': 'Cassettes For Kids & Tom Jarmey ', 'album': 'UNIT01 ', 'year': '2019', 'date': 'Jan 27, 2019', 'genres': ['Electronic', 'EP', 'House'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-9617904.jpg', 'label': 'Unit Two', 'catalog': 'UNIT01'}
# New World Music  Intellectual Thinking  2019
# Jan 27, 2019
# ['Album', 'Boogie', 'Disco', 'Funk', 'Soul', 'Synth']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-1178271.jpg
# Numero Group NUM803
# {'url': 'https://nodata.tv/167678', 'artist': 'New World Music ', 'album': 'Intellectual Thinking ', 'year': '2019', 'date': 'Jan 27, 2019', 'genres': ['Album', 'Boogie', 'Disco', 'Funk', 'Soul', 'Synth'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-1178271.jpg', 'label': 'Numero Group', 'catalog': 'NUM803'}
# Krikor  Building Arnold Schwarzenegger  2019
# Jan 27, 2019
# ['Ambient', 'Electronic', 'Experimental', 'House', 'Soundtrack', 'Synth Wave', 'Techno']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13082753.jpg
# Self-released none
# {'url': 'https://nodata.tv/167696', 'artist': 'Krikor ', 'album': 'Building Arnold Schwarzenegger ', 'year': '2019', 'date': 'Jan 27, 2019', 'genres': ['Ambient', 'Electronic', 'Experimental', 'House', 'Soundtrack', 'Synth Wave', 'Techno'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13082753.jpg', 'label': 'Self-released', 'catalog': 'none'}
# Calibre  Break That  2018
# Jan 27, 2019
# ['Bass', 'Electronic', 'EP', 'Grime', 'House', 'UK Garage']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13094484.jpg
# The Nothing Special TNS027
# {'url': 'https://nodata.tv/167722', 'artist': 'Calibre ', 'album': 'Break That ', 'year': '2018', 'date': 'Jan 27, 2019', 'genres': ['Bass', 'Electronic', 'EP', 'Grime', 'House', 'UK Garage'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13094484.jpg', 'label': 'The Nothing Special', 'catalog': 'TNS027'}
# Joe Cleen  SBEDITZ004  2018
# Jan 27, 2019
# ['Disco', 'Electronic', 'EP', 'House']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12699641.jpg
# SlothBoogie Editz SBEDITZ004
# {'url': 'https://nodata.tv/167692', 'artist': 'Joe Cleen ', 'album': 'SBEDITZ004 ', 'year': '2018', 'date': 'Jan 27, 2019', 'genres': ['Disco', 'Electronic', 'EP', 'House'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12699641.jpg', 'label': 'SlothBoogie Editz', 'catalog': 'SBEDITZ004'}
# Lo Kindre  Chlorophytum  2019
# Jan 27, 2019
# ['Drone', 'Dub', 'Electronic', 'EP', 'Experimental', 'Leftfield']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13039009.jpg
# 12th Isle ISLE007
# {'url': 'https://nodata.tv/167720', 'artist': 'Lo Kindre ', 'album': 'Chlorophytum ', 'year': '2019', 'date': 'Jan 27, 2019', 'genres': ['Drone', 'Dub', 'Electronic', 'EP', 'Experimental', 'Leftfield'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13039009.jpg', 'label': '12th Isle', 'catalog': 'ISLE007'}
# Tsuruda  Internet Slaps Vol. 2  2019
# Jan 27, 2019
# ['Album', 'Electronic', 'Experimental', 'Hip Hop', 'House', 'Juke', 'Trap']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-11199302.jpg
# Self-released none
# {'url': 'https://nodata.tv/167686', 'artist': 'Tsuruda ', 'album': 'Internet Slaps Vol. 2 ', 'year': '2019', 'date': 'Jan 27, 2019', 'genres': ['Album', 'Electronic', 'Experimental', 'Hip Hop', 'House', 'Juke', 'Trap'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-11199302.jpg', 'label': 'Self-released', 'catalog': 'none'}
# Villa Åbo  Carpet Proof of Daily Reports  2019
# Jan 27, 2019
# ['Acid', 'Album', 'Electronic', 'Experimental', 'House', 'Techno']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13086293.jpg
# iDEAL iDEAL168
# {'url': 'https://nodata.tv/167694', 'artist': 'Villa Åbo ', 'album': 'Carpet Proof of Daily Reports ', 'year': '2019', 'date': 'Jan 27, 2019', 'genres': ['Acid', 'Album', 'Electronic', 'Experimental', 'House', 'Techno'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13086293.jpg', 'label': 'iDEAL', 'catalog': 'iDEAL168'}
# Massimo Magrini  Vrachnas  2019
# Jan 27, 2019
# ['Abstract', 'Ambient', 'Electronic', 'Experimental', 'Musique Concrète']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12873174.jpg
# Backwards BWCD04
# {'url': 'https://nodata.tv/167718', 'artist': 'Massimo Magrini ', 'album': 'Vrachnas ', 'year': '2019', 'date': 'Jan 27, 2019', 'genres': ['Abstract', 'Ambient', 'Electronic', 'Experimental', 'Musique Concrète'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12873174.jpg', 'label': 'Backwards', 'catalog': 'BWCD04'}
# Various Artists  Heroes II  2019
# Jan 25, 2019
# ['Breaks', 'Disco', 'Electronic', 'EP', 'House', 'Various Artists']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-1246524.jpg
# Too Many Cars TMCREC002
# {'url': 'https://nodata.tv/167682', 'artist': 'Various Artists ', 'album': 'Heroes II ', 'year': '2019', 'date': 'Jan 25, 2019', 'genres': ['Breaks', 'Disco', 'Electronic', 'EP', 'House', 'Various Artists'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-1246524.jpg', 'label': 'Too Many Cars', 'catalog': 'TMCREC002'}
# DJ Fulltono  Before The Storm  2019
# Jan 25, 2019
# ['Bass', 'Dubstep', 'Electronic', 'EP', 'Footwork', 'Juke']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13054116.jpg
# Exit EXIT080
# {'url': 'https://nodata.tv/167710', 'artist': 'DJ Fulltono ', 'album': 'Before The Storm ', 'year': '2019', 'date': 'Jan 25, 2019', 'genres': ['Bass', 'Dubstep', 'Electronic', 'EP', 'Footwork', 'Juke'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13054116.jpg', 'label': 'Exit', 'catalog': 'EXIT080'}
# Tarjei Nygård  Lost in Lindos  2019
# Jan 25, 2019
# ['Balearic', 'Downtempo', 'Electronic', 'EP', 'House', 'Leftfield', 'Techno']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-6389661.jpg
# ESP Institute ESP073
# {'url': 'https://nodata.tv/167619', 'artist': 'Tarjei Nygård ', 'album': 'Lost in Lindos ', 'year': '2019', 'date': 'Jan 25, 2019', 'genres': ['Balearic', 'Downtempo', 'Electronic', 'EP', 'House', 'Leftfield', 'Techno'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-6389661.jpg', 'label': 'ESP Institute', 'catalog': 'ESP073'}
# Our Lady Of The Flowers  Holiday In Thule  2019
# Jan 25, 2019
# ['Album', 'Ambient', 'Dub', 'Electronic', 'Field Recording', 'Techno']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13044725.jpg
# 13 SPS1830
# {'url': 'https://nodata.tv/167708', 'artist': 'Our Lady Of The Flowers ', 'album': 'Holiday In Thule ', 'year': '2019', 'date': 'Jan 25, 2019', 'genres': ['Album', 'Ambient', 'Dub', 'Electronic', 'Field Recording', 'Techno'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13044725.jpg', 'label': '13', 'catalog': 'SPS1830'}
# DJ Fett Burger & Stiletti Ana  358 Men  2018
# Jan 25, 2019
# ['Album', 'Disco', 'Electronic', 'House', 'Leftfield']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12108073.jpg
# Freakout Cult CULT10
# {'url': 'https://nodata.tv/167625', 'artist': 'DJ Fett Burger & Stiletti Ana ', 'album': '358 Men ', 'year': '2018', 'date': 'Jan 25, 2019', 'genres': ['Album', 'Disco', 'Electronic', 'House', 'Leftfield'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12108073.jpg', 'label': 'Freakout Cult', 'catalog': 'CULT10'}
# Umwelt & Ryan James Ford  Untitled  2018
# Jan 25, 2019
# ['Electronic', 'EP', 'Techno']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12814277.jpg
# Repitch RPTCH09
# {'url': 'https://nodata.tv/167700', 'artist': 'Umwelt & Ryan James Ford ', 'album': 'Untitled ', 'year': '2018', 'date': 'Jan 25, 2019', 'genres': ['Electronic', 'EP', 'Techno'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12814277.jpg', 'label': 'Repitch', 'catalog': 'RPTCH09'}
# James Welsh  Hammers  2019
# Jan 25, 2019
# ['Acid', 'Electronic', 'EP', 'House', 'Techno']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13089904.jpg
# Futureboogie FBR063
# {'url': 'https://nodata.tv/167615', 'artist': 'James Welsh ', 'album': 'Hammers ', 'year': '2019', 'date': 'Jan 25, 2019', 'genres': ['Acid', 'Electronic', 'EP', 'House', 'Techno'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13089904.jpg', 'label': 'Futureboogie', 'catalog': 'FBR063'}
# Kamikaze Space Programme & Eomac  ETXC004  2018
# Jan 25, 2019
# ['Electronic', 'EP', 'Experimental', 'Industrial', 'Noise']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12918744.jpg
# Eotrax ETXC004
# {'url': 'https://nodata.tv/167508', 'artist': 'Kamikaze Space Programme & Eomac ', 'album': 'ETXC004 ', 'year': '2018', 'date': 'Jan 25, 2019', 'genres': ['Electronic', 'EP', 'Experimental', 'Industrial', 'Noise'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12918744.jpg', 'label': 'Eotrax', 'catalog': 'ETXC004'}
# R.H.G.T.  Depersonalisation  2019
# Jan 25, 2019
# ['Album', 'Electronic']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-1571197.jpg
# Opal Tapes OPAL137
# {'url': 'https://nodata.tv/167688', 'artist': 'R.H.G.T. ', 'album': 'Depersonalisation ', 'year': '2019', 'date': 'Jan 25, 2019', 'genres': ['Album', 'Electronic'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-1571197.jpg', 'label': 'Opal Tapes', 'catalog': 'OPAL137'}
# Kluentah  001  2018
# Jan 25, 2019
# ['Acid', 'Electronic', 'EP']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12926834.jpg
# Zement ZMNT001
# {'url': 'https://nodata.tv/167611', 'artist': 'Kluentah ', 'album': '001 ', 'year': '2018', 'date': 'Jan 25, 2019', 'genres': ['Acid', 'Electronic', 'EP'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12926834.jpg', 'label': 'Zement', 'catalog': 'ZMNT001'}
# Gonçalo Penas  Ego De Espinhos  2019
# Jan 25, 2019
# ['Abstract', 'Album', 'Drone', 'Electronic', 'Experimental', 'Noise']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13090027.jpg
# Subtext SUB027
# {'url': 'https://nodata.tv/167684', 'artist': 'Gonçalo Penas ', 'album': 'Ego De Espinhos ', 'year': '2019', 'date': 'Jan 25, 2019', 'genres': ['Abstract', 'Album', 'Drone', 'Electronic', 'Experimental', 'Noise'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13090027.jpg', 'label': 'Subtext', 'catalog': 'SUB027'}
# JAK3  Earth Four: Moonlight Radiation  2019
# Jan 25, 2019
# ['Abstract', 'Album', 'Ambient', 'Electronic', 'Hip Hop', 'Industrial', 'Jungle', 'Noise', 'Trap']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12972924.jpg
# Origin Peoples OPX26
# {'url': 'https://nodata.tv/167609', 'artist': 'JAK3 ', 'album': 'Earth Four: Moonlight Radiation ', 'year': '2019', 'date': 'Jan 25, 2019', 'genres': ['Abstract', 'Album', 'Ambient', 'Electronic', 'Hip Hop', 'Industrial', 'Jungle', 'Noise', 'Trap'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12972924.jpg', 'label': 'Origin Peoples', 'catalog': 'OPX26'}
# Selm  Kreise  2019
# Jan 25, 2019
# ['Album', 'Bass', 'Electronic', 'Experimental', 'Industrial', 'Noise', 'Techno']
# https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13116330.jpg
# Opal Tapes OPAL138
# {'url': 'https://nodata.tv/167690', 'artist': 'Selm ', 'album': 'Kreise ', 'year': '2019', 'date': 'Jan 25, 2019', 'genres': ['Album', 'Bass', 'Electronic', 'Experimental', 'Industrial', 'Noise', 'Techno'], 'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13116330.jpg', 'label': 'Opal Tapes', 'catalog': 'OPAL138'}

# %%
browser.quit()

# %%
undergroundMusic
# Out:
# [{'url': 'https://nodata.tv/167726',
#   'artist': 'Antoni Maiovvi ',
#   'album': 'The Ken Russell ',
#   'year': '2018',
#   'date': 'Jan 30, 2019',
#   'genres': ['Electronic', 'EP', 'Techno'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12858214.jpg',
#   'label': 'OMNIDISC',
#   'catalog': 'OMD019'},
#  {'url': 'https://nodata.tv/167852',
#   'artist': 'Substance ',
#   'album': 'Rise and Shine ',
#   'year': '2019',
#   'date': 'Jan 30, 2019',
#   'genres': ['Electronic', 'EP', 'Experimental', 'Techno'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13085086.jpg',
#   'label': 'Ostgut Ton',
#   'catalog': 'OTON115'},
#  {'url': 'https://nodata.tv/167716',
#   'artist': 'Andrés ',
#   'album': 'D.ATLien ',
#   'year': '2018',
#   'date': 'Jan 30, 2019',
#   'genres': ['Electronic', 'EP', 'Funk', 'Hip Hop', 'House', 'Soul', 'World'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12765999.jpg',
#   'label': 'NDATL',
#   'catalog': 'NDATL021'},
#  {'url': 'https://nodata.tv/167706',
#   'artist': 'Golpe De Estado ',
#   'album': 'Liquido ',
#   'year': '2019',
#   'date': 'Jan 30, 2019',
#   'genres': ['Disco', 'Electronic', 'House', 'Single'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-10105957.jpg',
#   'label': 'Discos Capablanca',
#   'catalog': 'DISCODIECISEIS'},
#  {'url': 'https://nodata.tv/167840',
#   'artist': 'JH1.FS3 ',
#   'album': 'Trials and Tribulations ',
#   'year': '2019',
#   'date': 'Jan 30, 2019',
#   'genres': ['Album', 'Ambient', 'Electronic', 'Experimental', 'Industrial'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13139086.jpg',
#   'label': 'Dais',
#   'catalog': 'DAIS126'},
#  {'url': 'https://nodata.tv/167815',
#   'artist': 'Various Artists ',
#   'album': 'Jazz Is The Teacher – Funk Is The Preacher ',
#   'year': '2018',
#   'date': 'Jan 30, 2019',
#   'genres': ['Compilation', 'Funk', 'Jazz', 'Soul', 'Various Artists'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12846202.jpg',
#   'label': 'Soul Jazz',
#   'catalog': 'SJR423'},
#  {'url': 'https://nodata.tv/167838',
#   'artist': 'Free Level ',
#   'album': 'Blue Grass ',
#   'year': '2019',
#   'date': 'Jan 30, 2019',
#   'genres': ['Electronic', 'EP', 'New Wave', 'Synth-pop'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13047491.jpg',
#   'label': 'Into The Light',
#   'catalog': 'ITL009'},
#  {'url': 'https://nodata.tv/167813',
#   'artist': 'Martina Lussi ',
#   'album': 'Diffusion Is a Force ',
#   'year': '2019',
#   'date': 'Jan 30, 2019',
#   'genres': ['Abstract', 'Album', 'Ambient', 'Electronic'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13139866.jpg',
#   'label': 'Latency',
#   'catalog': 'LTNC016'},
#  {'url': 'https://nodata.tv/167842',
#   'artist': 'Various Artists ',
#   'album': 'Black Label Series 03 ',
#   'year': '2019',
#   'date': 'Jan 30, 2019',
#   'genres': ['Breaks',
#    'Drum n Bass',
#    'Electronic',
#    'EP',
#    'House',
#    'Leftfield',
#    'Minimal',
#    'Various Artists'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-8205088.jpg',
#   'label': 'Banoffee Pies',
#   'catalog': 'BPBL03'},
#  {'url': 'https://nodata.tv/167714',
#   'artist': 'Unknown Artist ',
#   'album': 'WASH#2 ',
#   'year': '2018',
#   'date': 'Jan 30, 2019',
#   'genres': ['Disco', 'Electronic', 'EP'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12420904.jpg',
#   'label': 'Delicate Wash',
#   'catalog': 'WASH#2'},
#  {'url': 'https://nodata.tv/167712',
#   'artist': 'De Gama ',
#   'album': 'Funktastic ',
#   'year': '2018',
#   'date': 'Jan 28, 2019',
#   'genres': ['Disco', 'Electronic', 'EP', 'Funk', 'House', 'Soul'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-11908298.jpg',
#   'label': 'Samosa',
#   'catalog': 'SMS004'},
#  {'url': 'https://nodata.tv/167702',
#   'artist': 'Coppice Halifax ',
#   'album': 'Etchings In Rust ',
#   'year': '2018',
#   'date': 'Jan 28, 2019',
#   'genres': ['Album', 'Ambient', 'Electronic', 'Techno'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-9656437.jpg',
#   'label': 'Self-released',
#   'catalog': 'none'},
#  {'url': 'https://nodata.tv/167809',
#   'artist': 'Pablo’s Eye ',
#   'album': 'Dark Matter ',
#   'year': '2019',
#   'date': 'Jan 28, 2019',
#   'genres': ['Ambient', 'Electronic', 'Experimental'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12855550.jpg',
#   'label': 'STROOM ',
#   'catalog': 'STRLP022'},
#  {'url': 'https://nodata.tv/167704',
#   'artist': 'German Army ',
#   'album': 'MOVE9 ',
#   'year': '2018',
#   'date': 'Jan 28, 2019',
#   'genres': ['Album', 'Electronic', 'Experimental'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13021642.jpg',
#   'label': 'Fort Evil Fruit',
#   'catalog': 'FEF74'},
#  {'url': 'https://nodata.tv/167805',
#   'artist': 'Jigga ',
#   'album': 'iliiiilii ',
#   'year': '2019',
#   'date': 'Jan 28, 2019',
#   'genres': ['Ambient',
#    'Club',
#    'Drone',
#    'Dub',
#    'Electronic',
#    'EP',
#    'Experimental',
#    'Industrial',
#    'Leftfield',
#    'Shoegaze',
#    'Techno'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13043829.jpg',
#   'label': 'Bedouin',
#   'catalog': 'BDN022'},
#  {'url': 'https://nodata.tv/167530',
#   'artist': 'Ami Shavit ',
#   'album': 'Yom Kippur 1973 ',
#   'year': '2019',
#   'date': 'Jan 28, 2019',
#   'genres': ['Abstract',
#    'Album',
#    'Ambient',
#    'Electronic',
#    'Experimental',
#    'Synth Wave'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13095501.jpg',
#   'label': 'Sub Rosa',
#   'catalog': 'SRV456'},
#  {'url': 'https://nodata.tv/167728',
#   'artist': 'Jay Glass Dubs ',
#   'album': 'Epitaph ',
#   'year': '2019',
#   'date': 'Jan 28, 2019',
#   'genres': ['Album',
#    'Dub',
#    'Electronic',
#    'Experimental',
#    'Industrial',
#    'Leftfield'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13078300.jpg',
#   'label': 'Bokeh Versions',
#   'catalog': 'BKV023'},
#  {'url': 'https://nodata.tv/167698',
#   'artist': 'Various Artists ',
#   'album': 'Casa Sports Vol.2 ',
#   'year': '2018',
#   'date': 'Jan 28, 2019',
#   'genres': ['Electronic', 'EP', 'House', 'Techno', 'Various Artists'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12713202.jpg',
#   'label': 'Casa Voyager',
#   'catalog': 'CSV04'},
#  {'url': 'https://nodata.tv/167724',
#   'artist': 'Cassettes For Kids & Tom Jarmey ',
#   'album': 'UNIT01 ',
#   'year': '2019',
#   'date': 'Jan 27, 2019',
#   'genres': ['Electronic', 'EP', 'House'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-9617904.jpg',
#   'label': 'Unit Two',
#   'catalog': 'UNIT01'},
#  {'url': 'https://nodata.tv/167678',
#   'artist': 'New World Music ',
#   'album': 'Intellectual Thinking ',
#   'year': '2019',
#   'date': 'Jan 27, 2019',
#   'genres': ['Album', 'Boogie', 'Disco', 'Funk', 'Soul', 'Synth'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-1178271.jpg',
#   'label': 'Numero Group',
#   'catalog': 'NUM803'},
#  {'url': 'https://nodata.tv/167696',
#   'artist': 'Krikor ',
#   'album': 'Building Arnold Schwarzenegger ',
#   'year': '2019',
#   'date': 'Jan 27, 2019',
#   'genres': ['Ambient',
#    'Electronic',
#    'Experimental',
#    'House',
#    'Soundtrack',
#    'Synth Wave',
#    'Techno'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13082753.jpg',
#   'label': 'Self-released',
#   'catalog': 'none'},
#  {'url': 'https://nodata.tv/167722',
#   'artist': 'Calibre ',
#   'album': 'Break That ',
#   'year': '2018',
#   'date': 'Jan 27, 2019',
#   'genres': ['Bass', 'Electronic', 'EP', 'Grime', 'House', 'UK Garage'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13094484.jpg',
#   'label': 'The Nothing Special',
#   'catalog': 'TNS027'},
#  {'url': 'https://nodata.tv/167692',
#   'artist': 'Joe Cleen ',
#   'album': 'SBEDITZ004 ',
#   'year': '2018',
#   'date': 'Jan 27, 2019',
#   'genres': ['Disco', 'Electronic', 'EP', 'House'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12699641.jpg',
#   'label': 'SlothBoogie Editz',
#   'catalog': 'SBEDITZ004'},
#  {'url': 'https://nodata.tv/167720',
#   'artist': 'Lo Kindre ',
#   'album': 'Chlorophytum ',
#   'year': '2019',
#   'date': 'Jan 27, 2019',
#   'genres': ['Drone', 'Dub', 'Electronic', 'EP', 'Experimental', 'Leftfield'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13039009.jpg',
#   'label': '12th Isle',
#   'catalog': 'ISLE007'},
#  {'url': 'https://nodata.tv/167686',
#   'artist': 'Tsuruda ',
#   'album': 'Internet Slaps Vol. 2 ',
#   'year': '2019',
#   'date': 'Jan 27, 2019',
#   'genres': ['Album',
#    'Electronic',
#    'Experimental',
#    'Hip Hop',
#    'House',
#    'Juke',
#    'Trap'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-11199302.jpg',
#   'label': 'Self-released',
#   'catalog': 'none'},
#  {'url': 'https://nodata.tv/167694',
#   'artist': 'Villa Åbo ',
#   'album': 'Carpet Proof of Daily Reports ',
#   'year': '2019',
#   'date': 'Jan 27, 2019',
#   'genres': ['Acid', 'Album', 'Electronic', 'Experimental', 'House', 'Techno'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13086293.jpg',
#   'label': 'iDEAL',
#   'catalog': 'iDEAL168'},
#  {'url': 'https://nodata.tv/167718',
#   'artist': 'Massimo Magrini ',
#   'album': 'Vrachnas ',
#   'year': '2019',
#   'date': 'Jan 27, 2019',
#   'genres': ['Abstract',
#    'Ambient',
#    'Electronic',
#    'Experimental',
#    'Musique Concrète'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12873174.jpg',
#   'label': 'Backwards',
#   'catalog': 'BWCD04'},
#  {'url': 'https://nodata.tv/167682',
#   'artist': 'Various Artists ',
#   'album': 'Heroes II ',
#   'year': '2019',
#   'date': 'Jan 25, 2019',
#   'genres': ['Breaks',
#    'Disco',
#    'Electronic',
#    'EP',
#    'House',
#    'Various Artists'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-1246524.jpg',
#   'label': 'Too Many Cars',
#   'catalog': 'TMCREC002'},
#  {'url': 'https://nodata.tv/167710',
#   'artist': 'DJ Fulltono ',
#   'album': 'Before The Storm ',
#   'year': '2019',
#   'date': 'Jan 25, 2019',
#   'genres': ['Bass', 'Dubstep', 'Electronic', 'EP', 'Footwork', 'Juke'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13054116.jpg',
#   'label': 'Exit',
#   'catalog': 'EXIT080'},
#  {'url': 'https://nodata.tv/167619',
#   'artist': 'Tarjei Nygård ',
#   'album': 'Lost in Lindos ',
#   'year': '2019',
#   'date': 'Jan 25, 2019',
#   'genres': ['Balearic',
#    'Downtempo',
#    'Electronic',
#    'EP',
#    'House',
#    'Leftfield',
#    'Techno'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-6389661.jpg',
#   'label': 'ESP Institute',
#   'catalog': 'ESP073'},
#  {'url': 'https://nodata.tv/167708',
#   'artist': 'Our Lady Of The Flowers ',
#   'album': 'Holiday In Thule ',
#   'year': '2019',
#   'date': 'Jan 25, 2019',
#   'genres': ['Album',
#    'Ambient',
#    'Dub',
#    'Electronic',
#    'Field Recording',
#    'Techno'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13044725.jpg',
#   'label': '13',
#   'catalog': 'SPS1830'},
#  {'url': 'https://nodata.tv/167625',
#   'artist': 'DJ Fett Burger & Stiletti Ana ',
#   'album': '358 Men ',
#   'year': '2018',
#   'date': 'Jan 25, 2019',
#   'genres': ['Album', 'Disco', 'Electronic', 'House', 'Leftfield'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12108073.jpg',
#   'label': 'Freakout Cult',
#   'catalog': 'CULT10'},
#  {'url': 'https://nodata.tv/167700',
#   'artist': 'Umwelt & Ryan James Ford ',
#   'album': 'Untitled ',
#   'year': '2018',
#   'date': 'Jan 25, 2019',
#   'genres': ['Electronic', 'EP', 'Techno'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12814277.jpg',
#   'label': 'Repitch',
#   'catalog': 'RPTCH09'},
#  {'url': 'https://nodata.tv/167615',
#   'artist': 'James Welsh ',
#   'album': 'Hammers ',
#   'year': '2019',
#   'date': 'Jan 25, 2019',
#   'genres': ['Acid', 'Electronic', 'EP', 'House', 'Techno'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13089904.jpg',
#   'label': 'Futureboogie',
#   'catalog': 'FBR063'},
#  {'url': 'https://nodata.tv/167508',
#   'artist': 'Kamikaze Space Programme & Eomac ',
#   'album': 'ETXC004 ',
#   'year': '2018',
#   'date': 'Jan 25, 2019',
#   'genres': ['Electronic', 'EP', 'Experimental', 'Industrial', 'Noise'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12918744.jpg',
#   'label': 'Eotrax',
#   'catalog': 'ETXC004'},
#  {'url': 'https://nodata.tv/167688',
#   'artist': 'R.H.G.T. ',
#   'album': 'Depersonalisation ',
#   'year': '2019',
#   'date': 'Jan 25, 2019',
#   'genres': ['Album', 'Electronic'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-1571197.jpg',
#   'label': 'Opal Tapes',
#   'catalog': 'OPAL137'},
#  {'url': 'https://nodata.tv/167611',
#   'artist': 'Kluentah ',
#   'album': '001 ',
#   'year': '2018',
#   'date': 'Jan 25, 2019',
#   'genres': ['Acid', 'Electronic', 'EP'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12926834.jpg',
#   'label': 'Zement',
#   'catalog': 'ZMNT001'},
#  {'url': 'https://nodata.tv/167684',
#   'artist': 'Gonçalo Penas ',
#   'album': 'Ego De Espinhos ',
#   'year': '2019',
#   'date': 'Jan 25, 2019',
#   'genres': ['Abstract',
#    'Album',
#    'Drone',
#    'Electronic',
#    'Experimental',
#    'Noise'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13090027.jpg',
#   'label': 'Subtext',
#   'catalog': 'SUB027'},
#  {'url': 'https://nodata.tv/167609',
#   'artist': 'JAK3 ',
#   'album': 'Earth Four: Moonlight Radiation ',
#   'year': '2019',
#   'date': 'Jan 25, 2019',
#   'genres': ['Abstract',
#    'Album',
#    'Ambient',
#    'Electronic',
#    'Hip Hop',
#    'Industrial',
#    'Jungle',
#    'Noise',
#    'Trap'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-12972924.jpg',
#   'label': 'Origin Peoples',
#   'catalog': 'OPX26'},
#  {'url': 'https://nodata.tv/167690',
#   'artist': 'Selm ',
#   'album': 'Kreise ',
#   'year': '2019',
#   'date': 'Jan 25, 2019',
#   'genres': ['Album',
#    'Bass',
#    'Electronic',
#    'Experimental',
#    'Industrial',
#    'Noise',
#    'Techno'],
#   'cover': 'https://nodatatv.aigaion.feralhosting.com/images/2019/01/R-13116330.jpg',
#   'label': 'Opal Tapes',
#   'catalog': 'OPAL138'}]

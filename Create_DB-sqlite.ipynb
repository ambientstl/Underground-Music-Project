# %%
from sqlalchemy import create_engine, func
from sqlalchemy.orm import Session

from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Date, ForeignKey
 
import pymysql
pymysql.install_as_MySQLdb()

from splinter import Browser
from bs4 import BeautifulSoup as bs
import time

import datetime as dt

import wikipedia

# %%
#initialize browser
def init_browser():
    executable_path = {"executable_path": "chromedriver"}
    return Browser("chrome", **executable_path, headless=False)
browser = init_browser()

# %% [markdown]
# # Scrape Links

# %%
#set url
url = "https://nodata.tv/blog"
browser.visit(url)

time.sleep(1)

#scrape first page into Soup
html = browser.html
soup = bs(html, "html.parser")

links = []
#for pages 1 to 50
for i in range(1, 31):
    boxes = soup.find_all("article", class_="project-box")
    
    for box in boxes:
        link = box.find("a", class_="title")["href"]
        links.append(link)
        
    url = "https://nodata.tv/blog/page/" + str(1 + i)
    browser.visit(url)
    time.sleep(1)
    
    #scrape page into soup
    html = browser.html
    soup = bs(html, "html.parser")

# %% [markdown]
# # Scrape Album Info

# %%
undergroundMusic = []
for link in links:
    browser.visit(link)

    time.sleep(1)

    #scrape page into Soup
    html = browser.html
    soup = bs(html, "html.parser")
    
    #find main div
    main = soup.find("div", {"id": "main"})
    
    
    ### ARTIST, ALBUM, YEAR ###
    #find artist, album, year
    title = main.find("h4").text
#     print(title)
    try:
        split_title = title.split(" – ")
        artist = split_title[0]
        album = split_title[1].split(" [")[0]
    except IndexError:
        split_title = title.split(" / ")
        artist = split_title[0]
        album = split_title[1].split(" [")[0]
        
    #strip trailing whitespace from artist and album
    artist = artist.strip()
    album = album.strip()
        
    try:
        year = split_title[1].split(" [")[1].split("]")[0]
    except IndexError:
        #find metadata
        metadata = main.find("ul", class_="meta")
        #find blog post date and isolate year
        date = metadata.find_all("li")[1].text
        year = date.split(", ")[1]
    
    print("|"+artist+"|"+album+"|"+year+"|")
    
    
    ### DATE, GENRES ###
    #find metadata
    metadata = main.find("ul", class_="meta")
    #find date and convert to datetime object
    date = metadata.find_all("li")[1].text
    date = dt.datetime.strptime(date, "%b %d, %Y")
    #find genre tags in metadata
    tags = metadata.find_all("li")[2]
    tags = tags.find_all("a")
    #add tags to genres list
    genres = []
    for tag in tags:
        genre = tag.text
        genres.append(genre)
        
#     print("|"+date+"|")
#     print("|"+genres+"|")
    
    
    ### ALBUM ART ###
    #find cover img url
    cover_link = main.find("img")["src"]
    #remove 's' from https in link
    cover_link = cover_link.replace("s", "", 1)
#     print(cover_link)
        
    ### LABEL, CATALOG NUMBER ###
    #find label and catalog number
    label_text = main.find("section", class_="post").text
    label_text = label_text.replace("[", "")
    label_text = label_text.replace("]", "")
    label = label_text.split(":")[1].split("|")[0]
    try:
        catalog = label_text.split(":")[2].split("\n")[0]
    except IndexError:
        catalog = label_text.split("Cat#")[1].split("\n")[0]

    #strip whitespace from label and catalog
    label = label.strip()
    catalog = catalog.strip()
    print("|"+label+"|"+catalog+"|")
    
    #compile album info into dict
    albumInfo = {
        "url": link,
        "artist": artist,
        "album": album,
        "year": year,
        "date": date,
        "genres": genres,
        "cover": cover_link,
        "label": label,
        "catalog": catalog
    }
    # print(albumInfo)
    
    #add dict to underground music list
    undergroundMusic.append(albumInfo)
    
browser.quit()
# Out:
# |Omar-S|1992|2019|
# |FXHE|AOS(1992)|
# |Various Artists|Timeless Edits|2019|
# |Correcciones Calypso|CC001|
# |D.K.|Riding For A Fall|2019|
# |Antinote|ATN048|
# |Flora FM|Mycelination|2019|
# |TerraFirm®|TerraFirm 2|
# |Volor Flex|On The Roof|2019|
# |Self-released|none|
# |Various Artists|The Magic City|2019|
# |Hasana|XIX-I|
# |Alex.Do & Rødhåd|WSNWG002|2019|
# |WSNWG|WSNWG002|
# |Flying Lotus|Spontaneous / Takashi|2019|
# |Warp|WARP291|
# |Various Artists|ALERT!|2019|
# |Alter|ALT50|
# |Daniel Kovac|Base|2019|
# |Patch Series|PTS003|
# |Slick Shoota|VIP VAULTS|2019|
# |Self-released|none|
# |Maenad Veyl|Body Count|2019|
# |VEYL|VEYL007|
# |Bergsonist|Chaos|2019|
# |Börft|BÖRFT165|
# |Mesak|Sata EP|2019|
# |Orson|orson016|
# |Various Artists|META MOTO 3|2019|
# |META MOTO|MM003|
# |Various Artists|Corpora Part I|2019|
# |Sublunar|SUBT201|
# |Keith Fullerton Whitman|Generatorss|2019|
# |Self-released|none|
# |lastminuteman|Iamb|2019|
# |Jheri Tracks|JT8x12|
# |Fischerle & Persuasion|Winter Studies|2019|
# |Idioms|none|
# |Joshua Abrams & Natural Information Society|Mandatory Reality|2019|
# |Eremite|MTE7071|
# |Dolo Percussion|DOLO 4|2019|
# |Future Times|FTDIGI004|
# |FFT|Regional / Loss|2019|
# |The Trilogy Tapes|TTT076|
# |Lemna|Figure And Ground|2019|
# |Sacred Court|SCX06|
# |Plaid|Maru / Recall|2019|
# |Warp|WARPDD303A|
# |Rubbish TC|KamAZ|2019|
# |NEN|NEN28|
# |Assembler Code & Jensen Interceptor|Upper Function|2019|
# |LKR|LKR006|
# |Whodat & Viola Klein|Workshop 26|2019|
# |Workshop|WORKSHOP26|
# |Textasy|TEXAS TERRORTECH VOL.1|2019|
# |Self-released|none|
# |Various Artists|Touched Electronix 002|2019|
# |Touched Electronix|TE002|
# |Flaty|INSTRUMENT №6|2019|
# |ГОСТ ЗВУК|GIN006|
# |Diasiva|Thirst|2019|
# |Instruments Of Discipline|IOD039|
# |bsd.u|po33 + random beats (soundclout)|2019|
# |Self-released|none|
# |Régis Renouard Larivière|Contrée|2019|
# |Recollection GRM|REGRM021|
# |Various Artists|PS001​.​1|2019|
# |Pure Space|PS001.1|
# |Dance System|Wind ‘Em Up|2019|
# |Monkeytown|MTR097|
# |Emerson|If You Need Me, Call Me|2019|
# |Kalita|KALITA003|
# |London Modular Alliance|GALAXY EXPLORATION|2019|
# |PRIVATE PERSONS|PRIVATEPERSONS011|
# |Various Artists|Various Rats|2019|
# |Rat Life|RAT16|
# |Angel Molina & Svreca|Untitled|2019|
# |Semantica|SEMANTICAAa|
# |Logos|Imperial Flood|2019|
# |Different Circles|DIFFLP003|
# |Shiken Hanzo|The Centipede|2019|
# |A14|A1405|
# |Various Artists|Fashion Records: Style & Fashion|2019|
# |Soul Jazz|SJRD443|
# |Manuel Fischer|Roadkill Grill In Novosibirsk|2019|
# |Lobster Theremin|LT060|
# |New World Science|Osmos (Movements)|2019|
# |Temple|TMPL005|
# |Chinaski|S F X|2019|
# |Kitjen|KITJEN008|
# |Various Artists|Crash Klang Bang Thang|2019|
# |Jollies|JS001|
# |Fret|Fret|2019|
# |L.I.E.S.|LIES128|
# |D. Carbone & Umwelt|Rave Or Die 12|2019|
# |Rave Or Die|ROD12|
# |Új Bála|Diacritical Marks And Angels|2019|
# |Baba Vanga|VNG025|
# |Hamilton Scalpel|Hamilton Scalpel|2019|
# |Concrete Cabin|CC-ONE|
# |Bunny Lee|Dreads Enter the Gates With Praise: The Mighty Striker Shoots the Hits!|2019|
# |Soul Jazz|SJRD435|
# |Mumdance & Logos|Shapednoise Remixes|2019|
# |Tectonic|TEC106|
# |Soren Roi|Retrograde Amnesia|2019|
# |BANK|BNK017|
# |Various Artists|K.Y Space|2019|
# |Kynant|KYN012|
# |Gathaspar|Op. 3-4|2019|
# |Chypre|CHYPRE002|
# |Alberich|Quantized Angel|2019|
# |Hospital Productions|HOS577|
# |The Tapes|News From Nowhere|2019|
# |Luce Sia|066|
# |Goth-Trad & JK Flesh|Knights Of The Black Table|2019|
# |Daymare|DYMC320|
# |Dungeon Acid|Dungeon Acid|2019|
# |iDEAL|iDEAL186|
# |Textasy|Acid Eater / Burning Diesel|2019|
# |C-KNOW-EVIL|EVIL001|
# |Flaunt Edwards|The Name Is Flaunt|2018|
# |Leaving|LR120|
# |Cressida|Borneo Function|2019|
# |VOITAX|VOI015|
# |Cell Out|Oblong Room|2019|
# |Beatnik Boulevard|BEATB004|
# |Wolf Müller|Meets The Nile Project|2019|
# |Nouvelle Ambiance|AMBIANCE003|
# |Yuri|Menat|2019|
# |Janushoved|Janushoved no. 93|
# |Various Artists|Tashi Dorji / C. Spencer Yeh / Michael Zerang|2019|
# |8mm|8mm066|
# |Florian Kupfer|4 Ever|2019|
# |Axe Traxx|ATX009|
# |Skeptical|Fibonacci Sequence|2019|
# |Exit|EXIT083|
# |Caprithy & RNBWS|Pagan Mob|2019|
# |PKGE|PKGE01|
# |Geins’t Naït|Archives 1/3|2019|
# |Editions Gravats|GRVTS015|
# |The Fabulous Terrifics|Kiss My Tears Away|2019|
# |Numero Group|NUM5121|
# |._ \ •|_. EON|2019|
# |New York Trax|NYT08|
# |Bogdan Raczynski|Rave ‘Till You Cry|2019|
# |Disciples|DISC2|
# |Unknown Artist|Keep Your Mouth Shut 1|2018|
# |Not On Label|KYMS1|
# |Amnesia Scanner & Bill Kouligas|Lexachast|2019|
# |PAN|PAN83|
# |Ray Kandinski|Stenocactus Crispatus|2019|
# |Cactus Traxx|CCTS002|
# |Tim Jackiw|Endless Cycles|2019|
# |Offworld|Offworld004|
# |DJ Whipr Snipr|Friends Of Mine|2019|
# |Clipp.Art|CLIPP083|
# |Harmonious Thelonious|Kabriman|2019|
# |Midnight Shift|MNSX015|
# |Full Circle|Back To Disco Valley Volume 3|2019|
# |Crowdspacer|CRWDSPCRX007|
# |Various Artists|Fear And Anxieties 2/3|2019|
# |Semantica|SEMANTICA111.2|
# |Mana|Seven Steps Behind|2019|
# |Hyperdub|HDBCD043|
# |P.V.P.|Tshilidzi / Si Ya Jola|2019|
# |La Casa Tropical|CASA1201|
# |O Yuki Conjugate|Insect-Talk|2019|
# |Utter|UTTER3|
# |Sound Stream|Love Remedy|2019|
# |Sound Stream|SST08|
# |Igor Wakhévitch|Kshatrya (The Eye Of The Bird)|2019|
# |Transversales Disques|TRS10|
# |Various Artists|Various Artists #2|2019|
# |KUMP|KUMP4|
# |Edward|Hooked On Magic|2019|
# |Giegling|GIEGLING24|
# |Piezo|The Mandrake / Tinned|2019|
# |Version|version012|
# |Drone|Amphibious / Lucid Dreams|2019|
# |System Music|SYSTM025|
# |Tevo Howard|Post Modern Chicago|2019|
# |Chiwax|CTX05|
# |K.L. Hamilton|I’m Trying / RIP|2019|
# |Rip Pro|RSR1032|
# |Textasy & Nasty King Kurl|Bombers|2019|
# |777|77718|
# |Brainwaltzera|The Kids Are AI|2019|
# |Analogical Force|AF021|
# |Keller Crackers|KC|2019|
# |Marmo Music|marmo009|
# |ASUNA & Jan Jelinek|Signals Bulletin|2019|
# |Faitiche|faitiche19|
# |Various Artists|DRBAGAIN05|2019|
# |Dr Banana|DRBAGAIN05|
# |Philipp Otterbach|The Rest Is Bliss|2019|
# |Knekelhuis|KH021|
# |Tzusing|A Name Out of Place Collected|2019|
# |L.I.E.S.|LIES115|
# |Nathan Melja|Karibuni Music|2019|
# |Antinote|ATN047|
# |Temudo|Do Nothing And Be Wrong|2019|
# |AWRY|AWRY006|
# |Various Artists|Previously Undisclosed Rituals II|2019|
# |VEYL|VEYL006|
# |Foodman|ODOODO|2019|
# |Mad Decent|none|
# |Trus’me|No Harm|2019|
# |Groovement|GR033|
# |Roger 23|Is Demanding For A Cultural Negotiation|2019|
# |Ilian Tape|ITX014|
# |Chris Roux|Together|2019|
# |Roux|ERRR016|
# |Various Artists / Nigeria 70|No Wahala: Highlife, Afro-Funk & Juju 1973-1987|2019|
# |Strut|Strut – STRUT197|
# |Ovandra|Retrofuture|2019|
# |Ahrpe|AHRPE007|
# |Greg Beato|DADE|2018|
# |NI UN PERO|UNPE02|
# |Chrissy|True Stories|2019|
# |Super Rhythm Trax|SRTX026|
# |Itsu|Typography|2019|
# |Detroit Underground|DETUNDLTD41|
# |The Pulse Projects|Nonfunctional|2019|
# |Opal Tapes|OPAL145|
# |Sage Caswell|Evil Twin|2019|
# |2MR|2MR040|
# |Look Like|Garden Of Eden|2019|
# |Royal Oak|ROYAL045|
# |DJ Sports|Akrasia|2019|
# |Help|HELP013|
# |Adiel & Donato Dozzy|Cavallina|2019|
# |Danza Tribale|DNZT005|
# |Phew / Ambarchi / Jim O’Rourke|Patience Soup|2019|
# |Black Truffle|BT046|
# |MC Gels|Wandering Souls Demos|2019|
# |Chopped Herring|CHMCGELS452|
# |Slow White Fall|Total|2019|
# |Downwards|LIN082|
# |Custodian Of Records|Collection Plate: Vol 1|2019|
# |Chipped Hearing|CHCUSTOD01|
# |FaltyDL & Benny Ill|FaltyDL x Benny Ill|2019|
# |Blueberry|BBR017D|
# |Domenico Crisci|Velvet|2019|
# |Black Opal|BOP018|
# |Don’t DJ|Laniakea|2019|
# |Honest Jon’s|HJP087|
# |Delroy Edwards|Wagon Wheels|2019|
# |L.I.E.S.|LIES129|
# |Luke Abbott|Music From The Edge Of An Island|2019|
# |Float|FLOAT003|
# |Slick Master Rick|Factory Jack Muzik (1987-1988)|2019|
# |Midnight Shift|MNSX014|
# |Various Artists|Ziemia 001|2019|
# |Ziemia|EARTH001|
# |Various Artists|Oscillate Tracks 002|2019|
# |Oscillate Tracks|OSCT002|
# |Gamma Intel|Motives & Methods|2019|
# |Pinkman|PNKMN26|
# |Fennesz|Agora|2019|
# |Touch|TO|
# |Mdou Moctar|Ilana: The Creator|2019|
# |Sahel Sounds|SS051|
# |Clang83|Keep On Reaching|2019|
# |Sel-released|GYPSY001|
# |Marsellus Wallace|Navigazione Spaziale|2019|
# |Origin Peoples|OPX28|
# |Changez|Slownotion|2019|
# |Regelbau|RB09|
# |Kyle Bobby Dunn|From Here To Eternity|2019|
# |Past Inside The Present|PITPV001|
# |Various Artists|Haŵs Party Vol. 1|2018|
# |Haŵs|HAWS001|
# |AIROD|Universe Remix|2019|
# |Molekül|MLKL015|
# |URUK|The Descent Of Inanna|2019|
# |CAVE12|C12A06|
# |Vin Sol|808 Tele Funk|2019|
# |Jupiter4|JPT004|
# |Francis Harris & Hamatsuki|Archive Fever|2019|
# |Horoom|HRM001|
# |Head High|Into It|2019|
# |Power House|PH10010|
# |Various Artists|Mechatronica White 1|2018|
# |Mechatronica White|MTRONW001|
# |Linnuissa|Vihreä Talo|2019|
# |True Aether|TRAE006|
# |Jeremy Hyman|FT048A|2019|
# |Future Times|FT048A|
# |Mystica Tribe|DJ Sotofett’s Dub Ash Mixes|2019|
# |Solar Phenomena|SOLAR11|
# |Dolenz|Dolenz|2019|
# |Exit|EXIT084|
# |Silvestre|All The Things|2019|
# |Padre Himalaya|PH004|
# |Various Artists|CULTED004|2019|
# |Cult Edits|CULTED004|
# |Salford Electronics|Deconstruction|2019|
# |Hospital Productions|HOS608|
# |Various Artists|Haŵs Party Vol. 2|2019|
# |Haŵs|HAWS002|
# |Paisiel|Paisiel|2019|
# |Lovers & Lollypops|L&L#086|
# |Steve Murphy|Mira Electronics|2019|
# |Lobster Theremin|LT056|
# |Sikka Rymes|Love Di People|2019|
# |Bokeh Versions|BKV024|
# |Various Artists|CULTED003|2018|
# |Cult Edits|CULTED003|
# |Gacha Bakradze|Monument|2019|
# |Fever AM|FAM04|
# |Bartellow & Ground|Amanogawa|2019|
# |SVS|SVS014|
# |Koehler|Melencolia V / Invidiosa|2019|
# |ESP Institute|ESP065|
# |Various Artists|Dungeon Rap: The Introduction|2019|
# |Natural Sciences|NATURAL027|
# |Ohmme|At Night / Give Me Back My Man|2019|
# |Joyful Noise|JNR293|
# |Vanessa Worm|Z TIME|2019|
# |Optimo Music|OMDD007|
# |Maruwa|Steel City Dance Discs Volume 10|2019|
# |Steel City Dance Discs|SCDD010|
# |EQ Why|Loops & Loud|2019|
# |Self-released|none|
# |Golden Baby|Forgotten World 1|2019|
# |All Possible Worlds|APW3|
# |Cold & James Bernard|Strobe Light Network / Lapis Lazuli|2019|
# |Forced Nostalgia|FN074|
# |Andy Garvey|Eternal Recurrence|2019|
# |Lobster Theremin|LT058|
# |Kainté Kountix|Assortiments|2019|
# |Ville Nouvelle|VNC007|
# |HomeSick|Burnout 2099|2019|
# |Defrostatica|DICA010|
# |Polonius|Shades of Paradise|2019|
# |Artetetra|ATA24|
# |Sabrina Rich|Smooth Operator|2019|
# |Cultures Of Soul|COS50812|
# |Golden Baby|Forgotten World 2|2019|
# |All Possible Worlds|APW4|
# |Etnik Sentetik|Selected Works 1995-2006|2018|
# |Müstesna|MSTSN001|
# |Opus|Crumble|2019|
# |Chestplate|CHST046|
# |Joachim Nordwall|Communication Is The Key|2019|
# |Entr’acte|E235|
# |Sound Mercenary & Groove Mercenary|Dilemma / Switch|2019|
# |STROOM|STR12021|
# |Gil.Barte|Sssjp|2018|
# |Neubau|BAU008|
# |Ivy Lab|Gunk|2019|
# |20/20 LDN|2020LDN015|
# |URA|Entertainment|2019|
# |Collect-Call|CC006|
# |Felix Kubin|Max Brand Studie IV / T O P I A|2019|
# |V I S|KUBIN|
# |Gunnar Haslam|Cacique De Poyais|2019|
# |Delsin|133dsr|
# |MATstudio|MATstudio 1|2019|
# |Melody As Truth|MAT-ss1|
# |Placid Angles|First Blue Sky|2019|
# |Magicwire|MAGIC017|
# |DJ Trance & Darwin Chamber|Indians And Aliens|2019|
# |Kalahari Oyster Cult|OYSTER14|
# |The Comet Is Coming|Trust In The Lifeforce Of The Deep Mystery|2019|
# |Impulse!|none|
# |Vieo Abiungo|The Dregs|2019|
# |Lost Tribe Sound|LTS043|
# |D.K.|The Goddess Is Dancing|2019|
# |Good Morning Tapes|GMT21|
# |Dexter Story|Bahir|2019|
# |Soundway|SNDW128|
# |Telephones|From The Vaults 1998-2018 Vol.1|2019|
# |European Carryall|EC01/TLF01|
# |Kutmah|=|2019|
# |Self-released|none|
# |RAP|Export|2019|
# |Jolly Discs|none|
# |Liluzu|What’s Your Star Sign?|2019|
# |Kalahari Oyster Cult|OYSTER16|
# |Sun Ra & His Arkestra|The Spirit of Jazz Cosmos Arkestra|2019|
# |Self-released|none|
# |Various Artists|SPORTS|2019|
# |Youth|YOCD2|
# |Tzusing & M.E.S.H.|Split|2019|
# |PAN|PAN95|
# |The Pilotwings|Psytube|2019|
# |Animals Dancing|ANIMALS006|
# |Various Artists|London to Addis|2019|
# |No Hats No Hoods|NHNH137|
# |Savile|The Abolitionist|2019|
# |Self-released|none|
# |Dis Fig|PURGE|2019|
# |PTP|PTP2013|
# |Star Band de Dakar|Psicodelia Afro-Cubana de Senegal|2019|
# |Ostinato|OST006|
# |Garum|Garum|2019|
# |The Trilogy Tapes|TTT078|
# |Various Artists|The Noise Of Art: Works for Intonarumori|2019|
# |Sub Rosa|SR477V|
# |Thunder Tillman|Condor Sunflower|2019|
# |ESP Institute|ESP089|
# |Papillon|Cercueil Flottant|2019|
# |Sucata Tapes|SUC22|
# |OL|Saigon Special Room|2019|
# |Muscut|MUSCUT11|
# |BFM|Limitless|2019|
# |Cella|CELLA004|
# |Bilge Pump|We Love You|2019|
# |Gringo|WAAT069|
# |The Caretaker / Everywhere at the End of Time|Stage 6|2019|
# |History Always Favours The Winners|HAFTW030|
# |Anothernonagon|Anothernonagon|2019|
# |Self-released|none|
# |Galaxy Lane|Voyager 1|2019|
# |Lone Romantic|LR012|
# |Pedro|She Is|2019|
# |Wolf Music|WOLFEP049|
# |Internazionale|One Shot, One Life|2019|
# |Janushoved|Janushoved no. 90|
# |DJ Rubio|Western Medicine|2019|
# |Man Band|MNBN07|
# |Limited Toss|Altered State Of Mind|2019|
# |Tripalium|DMS029|
# |Various Artists|Eminent Domain|2019|
# |L.I.E.S.|LIES125|
# |DiSKOP|Blow Up / Outcome|2019|
# |Whiteloops|WHITELOOPS13|
# |Lakker|Época|2019|
# |R & S|RS1903|
# |Various Artists|META MOTO 2|2018|
# |META MOTO|MM002|
# |Ryong|Ryong|2019|
# |Janushoved|Janushoved no. 89|
# |Norken|Norken|2019|
# |Third Ear|3EEP201805|
# |Hardy Fox|25 Minus Minutes|2019|
# |TOOK|TOOK5|
# |Basic Rhythm|New Style|2019|
# |Sneaker Social Club|SNKR017|
# |Jessica Kert|DW|2019|
# |Detroit Underground|DUMGV4|
# |Memotone|Luaka / Sidewise Dub|2019|
# |Diskotopia|DSK046|
# |Trackmaster Dre|Konnektin Dots|2019|
# |Odd Even|ODDEVEN023|
# |Rian Treanor|ATAXIA|2019|
# |Planet Mu|ZIQ405|
# |Kilchhofer Anklin|Moto Perpetuo|2019|
# |Marionette|Marionette09|
# |Konduku|Gegek|2019|
# |Nous’klaer Audio|K2|
# |Robert Ouimet|Edits|2018|
# |Basic Fingers|FINGER032|
# |MOPCUT|Accelerated Frames Of Reference|2019|
# |Trost|TR185|
# |Sir Hiss|Rolling|2019|
# |White Peach|WPR039|
# |Kokoroko|Kokoroko|2019|
# |Brownswood|BWOOD199|
# |Nikki Nair|Exit Strategy|2019|
# |Scuffed|SCUFFED014|
# |Liam Ebbs|A Child’s Guide To Groove|2018|
# |Black Wattle|BWTL002|
# |Internazionale|Avatar In Life|2019|
# |Posh Isolation|PI226|
# |9T Antiope|Nocebo|2019|
# |PTP|PTP2012|
# |Levon Vincent|Slander / Late Night Reflections|2018|
# |Novel Sound|#19|
# |Sissel Wincent|Assorted Lights|2019|
# |Rösten|ROSTEN7|
# |Raquin|Dance Of The Peacock|2019|
# |Janushoved|Janushoved no. 91|
# |Metric Systems|People In The Dark|2018|
# |Best Effort|BE002|
# |STL|Nautic Nebulous|2019|
# |Something|SOMETHINGDGTSERIES52|
# |Mondkopf|How Deep Is Our Love?|2019|
# |Hands In The Dark|HIDT043|
# |V. Sinclair|A Name, For Desire|2019|
# |Total Black|105|
# |Station Rose|Gunafa’s Children|2019|
# |Childhood Intelligence|CHILD SIX|
# |Evitceles|Lioncage|2019|
# |Accents|ACCENTLP002|
# |Ole Mic Odd|Gimme My Shit|2018|
# |New York Haunted|NYH146|
# |Ruf Dug|Ruffy’s Island|2019|
# |Futureboogie|FBR064|
# |Restive Plaggona|Ego Driven|2019|
# |Several Minor Promises|none|
# |Gratitude|We Are Here to Party|2019|
# |Athens of the North|ATH076|
# |Various Artists|Fear And Anxieties 1​/3|2019|
# |Semantica|SEMANTICA111.1|
# |Don Zilla|From The Cave To The World|2019|
# |Hakuna Kulala|HK009|
# |Principleasure|I|2019|
# |Self-released|none|
# |Konrad Wehrmeister|Radiation|2019|
# |Hundert|HUNDERT104|
# |Various Artists|Cuneiform For Pumapunku|2019|
# |Light Sounds Dark|LSD027|
# |Machinefabriek|Zinder|2019|
# |Nomad Exquisite|NE008|
# |Your Planet Is Next|Gröna Stugans Väg|2018|
# |Gröna Stugans Väg|GSV001|
# |Svreca & Neel|Tángara Remixed.|2019|
# |Semantica|SEMANTICA104|
# |Simo Cell & Peter Van Hoesen|Sans Titre EP 02|2018|
# |Lavibe|LAVIBE002|
# |MSYLMA|Dhil-un Taht Shajarat Al-Zaqum|2019|
# |Halcyon Veil|HALC027|
# |M. Sage|Catch a Blessing|2019|
# |Geographic North|GN52|
# |Clara!|Meiga de Acero|2019|
# |Editions Gravats|BZH005|
# |Sepehr|Cybernetic|2019|
# |EON|EON001|
# |Claus Comedi|La Historia De Tu Alma|2019|
# |Waving Hands|WH019|
# |Fabrizio Fattori|Mediterranean Africa|2019|
# |Best Record|BSTX052|
# |Book Of Love & KnickKnack|Verlorene Seelen / Freudlos (M.W. Cuts)|2018|
# |Aspecto Humano|AH004|
# |Mark Du Mosch|The Heavens|2019|
# |Something Happening, Somewhere|SoHaSo 022|
# |Paul Jansen & Zn.|De Toerisme|2019|
# |De Vrije Keijser|DVK001|
# |Geffen|Ultima Weapon|2019|
# |Rawax|RAWAX023|
# |ASOK|How It Is|2019|
# |Lobster Theremin|LTWHT017|
# |Roland Jones|Strictly Dirt Vol. 1|2019|
# |Sound Transitions|ST009|
# |William Basinski|On Time Out of Time|2019|
# |Temporary Residence|TRR311|
# |Gnork|New Jams|2019|
# |Earth Waves|Earth Waves 0011|
# |Sully|UH-02|2019|
# |Uncertain Hour|UH02|
# |Pacific Coliseum|Ocean City (Remixes)|2019|
# |Coastal Haze|HAZE010|
# |Shelter|Profondeur 4000|2018|
# |Growing Bin|GBR016|
# |Jack Roland|Control / Applications|2018|
# |Natural Sciences|NATURAL022|
# |Christopher Whitley|Solos|2019|
# |Fluid|none|
# |Lila Tirando A Violeta|Sentient|2019|
# |New Motion|NM031|
# |A Handful of Dust|Dragging Her Wings of Rusty Knives: Selected Recordings 1994-2016|2019|
# |Self-released|none|
# |Teakup|Miscellanea I|2018|
# |is / was|IW05|
# |Hans Castrup|Heterogeneous Cell Information|2019|
# |Karlrecords|KR063|
# |Nature Boy|Unreleased Ruffness 1993-1994|2019|
# |Nature Boy|NB02|
# |Otik|Stoned Ghost|2019|
# |Nous Disques|US021|
# |Thomas Gray & Liam Ebbs|3 Days, 2 Nights|2019|
# |Analogue Attic|AAR014|
# |Various Artists|Cipher|2019|
# |C.A.N.V.A.S.|CANVAS004|
# |Marco Shuttle & Bambounou|Sans Titre EP 01|2018|
# |Lavibe|LAVIBE001|
# |Various Artists|Brat Tactics|2019|
# |Secret Studio|SCS09|
# |Janeret|Uchüsen|2019|
# |YoY|YoY.08|
# |FFT|In-side|2019|
# |Super Hexagon|SH004|
# |Nate Young|Volume Two: Nightshade|2019|
# |Lower Floor|LF007|
# |Zaliva-D|Forsaken|2019|
# |Knekelhuis|KH020|
# |SELA.|#BARS II|2018|
# |Self-released|none|
# |Yosuke Tokunaga|6 Nomads|2018|
# |Strange Rules|RULE157|
# |Emma DJ|Support Your Local Enemies|2019|
# |Lavibe|LAVIBE003|
# |Bôkaye’|Ethno Groove|1994|
# |New Music International|NMX070|
# |Jura Soundsystem|Monster Skies|2019|
# |Temples Of Jura|TEMPLE002|
# |My Disco|Environment|2019|
# |Downwards|DNLP024|
# |Zero Years Kid|Ongerijmde Rijmen|2019|
# |Eotrax|ETXLP002|
# |Various Artists|LTDBLBL002|2019|
# |Ltd, W/Lbl|LTDBLBL002|
# |Nummer|Daybreaker / 303 Of Life|2018|
# |Nummer|NUMM07|
# |Matmos|Plastic Anniversary|2019|
# |Thrill Jockey|thrill482|
# |D.K.|Mystic Warrior|2019|
# |Antinote|ATN046|
# |Snapped Ankles|Stunning Luxury|2019|
# |Leaf|BAY113E|
# |Various Artists|Edition 2|2019|
# |1985 Music|ONEF015|
# |Durand Jones & The Indications|American Love Call|2019|
# |Colemine|DOC177|
# |ELLLL|Confectionary|2019|
# |Glacial Industries|G1ND004|
# |Various Artists|Small Hours 001|2019|
# |Small Hours|SMALLHOURS001|
# |Yaporigami|We Dance Alone|2019|
# |Detroit Underground|DUDFSTN6|
# |Laurence Guy|Making Music Is Bad for Your Self Esteem|2019|
# |Studio Barnhus|BARN062|
# |Osborne|Fools|2019|
# |Spectral Sound|SPC142|
# |Stanley Schmidt|Smart Replies|2019|
# |Vienna|VIENNA002|
# |Terrine|Cheat Days|2019|
# |tanzprocesz|tzpLP11|
# |Not Waving & Jim O’Rourke|Side A / Side B|2019|
# |Diagonal|DIAG049|
# |1-800 GIRLS|U, Me and Madonna|2019|
# |clipp.art|CLIPPV001|
# |Beat Pharmacy|Molecular|2019|
# |Rohs!|ROHS!07/7″|
# |Grebenstein & Seefried|Raging Tender|2019|
# |Downwards|LIN081|
# |Stereotyp|Look Things|2019|
# |Seagrave|SR072|
# |Violet|New Visions|2019|
# |Paraiso|PARAISO005|
# |Nitric|Turd On The Dancefoor|2019|
# |New York Haunted|NYH66|
# |Pugilist|Chrysalis|2019|
# |Trusik|TRSK005|
# |Sofia Kourtesis|Sofia Kourtesis|2019|
# |Studio Barnhus|BARN058|
# |Shlohmo|Rock Music|2019|
# |Friends of Friends|FOF175B|
# |Various Artists|Music For Five Post Cards|2018|
# |Ville Nouvelle|VNC006|
# |Varg|Evanescence (A Love Letter)|2019|
# |Posh Isolation|PI224|
# |Lucas Croon|Lucas Croon|2019|
# |Aiwo rec.|AIWO006|
# |DJ Skechers x Yung Dolphin|LT-DOLPHSKECH-700X|2019|
# |Lobster Theremin|LTDOLPHSKECH700X|
# |Ras G & The Afrikan Space Program|Dance Of The Cosmos|2019|
# |Akashik|AKR012|
# |Voin Oruwu|Etudes From A Starship|2019|
# |Kvitnu|KVITNU63|
# |Various Artists|Various Artist Vol. 2|2019|
# |Forth|FORTH002|
# |Textasy|EXOTIC003|2019|
# |Exotic Robotics|EXOTIC003|
# |Jensen Interceptor|The Ultimate Wave Riding Vehicle|2019|
# |Craigie Knowes|CKNOWEP14|
# |Karima F|Karima F|2019|
# |Schloss|SCHL002|
# |W3C|Event Horizon|2019|
# |Infinite Machine|IM070|
# |Rising Sun|Realism II|2018|
# |Reality Used To Be A Friend Of Mine|R20183|
# |Pessimist|Austerity|2019|
# |Osiris|OSMUK055EP|
# |Food-Spotter|I Should Weigh Wonton|2019|
# |Aeronema|AERO039|
# |Nite Fleit|Overcast|2019|
# |Planet Euphorique|PE005|
# |Neuropunk|L.A. Story|2019|
# |Juke Bounce Werk|JBW024|
# |L/F/D/M|Perceived Symbolism|2019|
# |Clan Destine|CDRTP087|
# |Dark Star|Mix Tape 1989-1991|2019|
# |Dub Ito|DUBITO005|
# |Rose|Night Places|2019|
# |Constellation Tatsu|PURR0105|
# |Schacke|Welcome To The Pleasure Dome|2019|
# |Instruments of Discipline|IOD038|
# |Random Fluctuations|Skyscraper|2019|
# |Hybride Sentimento|HYB.002|
# |Charles.A.D|Inception|2019|
# |Umé|ume001|
# |Jordon Alexander|More Than I Ever Thought I Could / The Heart Is A Lonely Hunter|2019|
# |LOOKING FOR TROUBLE|LFT002|
# |Umwelt|Ecopoiesis|2019|
# |VOITAX|VOI014|
# |DeWalta|Lyra π|2019|
# |Meander|MEANDER26π|
# |Purl|Poems|2019|
# |ROHS!|ROHS!001JX|
# |DJ Aflow|Cent Force|2019|
# |Self-released|none|
# |Triad God|Triad|2019|
# |Presto!?|P!?032|
# |Delta Rain Dance|Trancemission/Transmission|2019|
# |Delta Rain Dance|DELTA1|
# |Tilliander|Expect Resistance / Respect Existence|2019|
# |Dub On Arrival|DOA01|
# |Amrint Keen|Transient Loss of Response|2019|
# |Uncanny Valley|UV049|
# |The Sensations|The Sensations: Demanding Men|2019|
# |Numero Group|NUM5113|
# |SVN / 2006|2014|2018|
# |Acido|Acido028|
# |Various Artists|Antologia de Música Atípica Portuguesa, Vol. 2|2019|
# |Discrepant|CREP61|
# |Drekka|No Tracks in the Snow|2019|
# |Dais|DAIS128|
# |Scratcha DVA x Gage|Flytnurse / Piffd|2019|
# |Keysound|LDN076|
# |Weird Weather|Leather Chair|2018|
# |Going Good|GOOD13|
# |Skee Mask|808BB|2019|
# |Ilian Tape|ISS003|
# |Bartosz Kruczyński & Poly Chain|Pulses|2019|
# |Into The Light|ITLIntl02|
# |Floorplan & Mark Broom|Floorplan v Mark Broom|2019|
# |ePM|EPM20V|
# |Jay Glass Dubs|Thumb Dub / Index Dub|2019|
# |Dub On Arrival|DOA02|
# |Bambounou|Whities 021|2019|
# |Whities|WHYT021|
# |Dale Cornish & Sim Hutchins|Decouple ][ Series|2019|
# |OOH-sounds|OOH012|
# |Jan Jelinek & Sven-Åke Johansson|puls-plus-puls|2019|
# |Ni-Vu-Ni-Connu|nvnc016|
# |Yves De Mey|Sueda|2019|
# |Line|LINE_101|
# |Private Press|Part Two|2018|
# |Indigo Aera|AERA022|
# |Various Artists|Ohrfeigen 001|2019|
# |Ohrfeigen|OHRFEIGEN001|
# |HLM38|Illicite Cong|2018|
# |KUMP|KUMP2|
# |Gobby|Beats By Gobby 2|2019|
# |UNO|none|
# |Mabuta|Welcome to This World Remixes|2019|
# |Self-released|none|
# |DJ Aflow|SMOG|2018|
# |Self-released|none|
# |Loraine James|Button Mashing|2019|
# |New York Haunted|NYH152|
# |Thighpaulsandra|Practical Electronics|2019|
# |Editions Mego|EMEGO258|
# |Various Artists|Shimazu Clan|2019|
# |Repertoire|REPRV018|
# |Ewa Justka|Acid On Acid|2019|
# |New York Haunted|NYH154|
# |DJ Manny|Let The Music Talk Vol. 1|2019|
# |Self-released|none|
# |S S S S|Absence|2019|
# |Haunter|SPCTR013|
# |L-R|The Rambler|2019|
# |Asking For Trouble|AFT004|
# |Klankman|Untitled|2019|
# |Bunker|BUNKER4012|
# |December|Night Of Nights|2019|
# |Pinkman|PBD15|
# |Drvg Cvltvre|Speed Riddims Vol. 1|2018|
# |New York Haunted|NYH162|
# |Jeff Mills|Str Mrkd|2019|
# |Axis|AX077|
# |Henning Baer|Rigger|2019|
# |Manhigh|MANHIGH007|
# |ELLLL|Febreeze|2019|
# |First Second|FSL007|
# |Various Artists|From da East #2|2019|
# |Increase The Groove|ITGR007|
# |DJ Nobu|ON-Netoh|2019|
# |No ‘Label’|RHD035NOBU|
# |Lokier|Fighting The Past|2019|
# |Pinkman|PNKMN25|
# |Various Artists|Anthology of Contemporary Music From Africa Continent|2019|
# |Unexplained Sounds Group|USG052|
# |Sawf|#009|2019|
# |Vanila|VNL009|
# |Code Walk|Distance|2019|
# |Peder Mannerfelt|PMCW001|
# |Ruins|Occasional Visits|2019|
# |STROOM|STREP023|
# |Realitycheck|Blank|2019|
# |Renascence|RNSC009|
# |Efdemin|New Atlantis|2019|
# |Ostgut Ton|OSTGUT45|
# |Mike Davis|Anti​-​Mimesis|2019|
# |Brenda|BRENDA010|
# |King Midas Sound|Solitude|2019|
# |Cosmo Rhythmatic|CR09|
# |Matpri|Vantuz|2019|
# |Slowdy Mowdy|SM007|
# |Mikael Lind|Contingencies|2019|
# |Archives|Archives54|
# |Various Artists|BPRDIGI06|2019|
# |Banoffee Pies|BPRDIGI06|
# |Szare|POLITY001|2019|
# |Polity|POLITY001|
# |Gray Chalk|Expressions Of Transactional Behaviour|2018|
# |Unvague|UNVG002|
# |K-LONE|Dance Of The Vampires|2019|
# |Idle Hands|IDLE056|
# |Eli Keszler|Empire|2019|
# |Shelter Press|SP107|
# |Power User|Perfect Selection|2019|
# |Self-released|none|
# |Midibasics|Planetarium|2018|
# |Midibasics|MIDIBASICS001|
# |Ulrich Troyer|Dolomite Dub|2019|
# |4Bit Productions|4Bit-P008|
# |Overloper|Overloper|2018|
# |Jericho One|Jericho One 08|
# |K-X-P|18 Hours (Of Love) An Optimo (Espacio) Remix / Tears (Extended Interlude) Mika Vainio Remix|2018|
# |Svart|SRE262|
# |Coco Bryce|Gunna / A New Mind|2018|
# |7th Storey Projects|7TH12026|
# |Powder|Powder In Space|2019|
# |Beats In Space|BIS036|
# |Nihiloxica|Biiri|2019|
# |Nyege Nyege Tapes|NNT014|
# |Viers|Lights Out|2019|
# |LPH WHITE|LPHWHT21|
# |Mang|Ritual|2019|
# |Genome6.66Mbp|GNM011|
# |Various Artists|Sounds From The Periphery|2019|
# |Periphery|PR001|
# |K15 & Kamaal Williams|Catch The Loop 1|2018|
# |Black Focus|none|
# |Aguila|The Club On 27th West|2019|
# |There Is Love In You|THEREISLOVE001|
# |Persian|Empire|2019|
# |Emotional Especial|EES031|
# |ASOK|Better Dead Than Alien|2019|
# |M>O>S|MOS025|
# |Kumasi|I Know You Feel It|2019|
# |Smiling C|SC#03|
# |Lucas Croon|Ascona|2019|
# |Themes For Great Cities|TFGC016|
# |Hadone|Defining Persuasion|2019|
# |Taapion|TAAPION011|
# |Adham Zahran|The Midnight Tower|2019|
# |We Play House|WPHTEN9|
# |Dawl & Sween|Rise of the Humanoids|2018|
# |Klasse Wrecks|WRECKS016|
# |Various Artists|Togo Soul 70: Edits & Rarities|2018|
# |Hot Casa|HC60|
# |Taso & Siete Catorce|Grandes Éxitos Vol. 1|2019|
# |NAAFI|none|
# |Androo|Hanko / Sync Dancehall|2018|
# |Poly Dance|POL001|
# |The Doubtful Guest|Voyage To Blacklantis|2018|
# |Arcola|ARC10|
# |Pye Corner Audio|Hollow Earth|2019|
# |Ghost Box|GBX032|
# |Glume & Phossa|Buried|2019|
# |White Peach|WPR038|
# |The Chi Factory|The Mantra Recordings|2019|
# |Astral Industries|AI12|
# |Franck Vigroux|Théorème|2019|
# |DAC|DAC045|
# |70’s Network|Netwurkkin|2019|
# |CHARBON|CHA01|
# |Mac-Talla Nan Creag|The Sorrow of Derdriu|2019|
# |Firecracker|FIREC027|
# |Bone Head|Soft Power|2018|
# |Arcola|ARC15|
# |S. Channel|Distant Shores|2019|
# |Freund Der Familie|FDFART01|
# |Passarani|W.O.W.|2019|
# |Offen|OFFEN010|
# |Ouer|Stingray Nebula|2019|
# |Dirt Crew|DIRT116|
# |Ground|Odoru Miyako|2019|
# |Chill Mountain Rec|CMR019|
# |Diane|The River By The Tree|2019|
# |Jungle Gym|JGT30|
# |DJ Di’jital|Electrohop1|2019|
# |TRUST|TRUST034|
# |Various Artists|PGH Electro Vol. 1|2018|
# |is / was|IW03|
# |Doubler|Lines of Force|2019|
# |U-Udios|UU3|
# |Ethiopian Records|Ye Feqer Edaye / የፍቅር እዳዬ|2018|
# |Arcola|ARC08|
# |P.H.O.R.K.|Timeloops|2019|
# |Self-released|none|
# |Various Artists|Passages from The Cuca Gospel|2019|
# |Numero|NUM5095dig1|
# |Ghostride The Drift|Ghostride The Drift|2019|
# |XPQ?|XPQ?0001|
# |Cosey Fanni Tutti|TUTTI|2019|
# |Conspiracy International|CTITUTTICD2018|
# |German Army|No No Boy|2019|
# |Phormix|PHXS04|
# |Various Artists|The Time Released Sound Around the World Ambient Program|2019|
# |Time Released Sound|TRS080|
# |Al Wootton|Selah|2019|
# |Trule|TRULE002|
# |Basic Rhythm|Dough Boy / Can’t You See?|2018|
# |Arcola|ARC16|
# |The Jaffa Kid|Start To End|2018|
# |La Beauté Du Négatif|LNEG009|
# |Walton|Inside|2019|
# |Tectonic|TEC105|
# |Sam Hostettler & La Leif|NX12X|2019|
# |NX|NX12X|
# |Ossia|Devil’s Dance|2019|
# |Blackest Ever Black|BLACKEST075|
# |DJ Juuko|Youth London|2019|
# |IDS|IDR003|
# |Muqata’a|Inkanakuntu|2018|
# |Souk|SOUK01|
# |Various Artists|Two Tribes|2019|
# |Agogo|AR113|
# |Only Thingz|Only Thingz|2018|
# |Good Morning Tapes|GMT07|
# |Volor Flex|Blowing Smoke|2019|
# |Apollo|AMB1902|
# |Senketsu No Night Club|Senketsu No Night Club|2019|
# |Dark Jazz|DJR005|
# |Khalab|Black Noise Remixed|2019|
# |On the Corner|OTCR12013|
# |Eartheater|IRISIRI Bonus|2018|
# |PAN|none|
# |Shedbug|The Krabben|2019|
# |1Ø Pills Mate|1ØPILLS009|
# |Afrikan Sciences|Culture Power|2019|
# |Self-released|none|
# |Not Waving|Futuro (Music for the Waldorf Project)|2019|
# |Ecstatic|ELP040|
# |Chameleon Sessions|Baobab Dubbings|2019|
# |Audio Recon|none|
# |Shanti Celeste & Hodge|Soba Dance|2019|
# |Peach|PEACH006|
# |Erell Ranson|Hand In Hand (The Remixes)|2019|
# |Kalahari Oyster Cult|OYSTER12|
# |TMSV|Funeral Bill / Sound Fi Dead|2019|
# |War Series|WAR022|
# |Dakim|Regos_Mined|2019|
# |Butter Made|none|
# |Odd Nosdam|Flippies Rock Tape|2019|
# |Self-released|none|
# |Omar-S|One of a Kind|2018|
# |FXHE|AOS7418|
# |Slikback|Tomo|2019|
# |Hakuna Kulala|HK001|
# |DJ Sotofett & Maimouna Haugen|C’Est L’Aventure|2018|
# |Honest Jon’s|HJP85|
# |Judaah|Sky Is The Limit|2018|
# |Good Morning Tapes|GMT11|
# |5ive|Planet Be|2019|
# |Thinner Groove|THINNER001|
# |Neana|Renegade Lakes|2019|
# |Horus|none|
# |DJ Manny|Turn Me Up|2019|
# |Aeronema|AERO038|
# |Dub Phizix & Fixate|ExitVs008|2018|
# |Exit|EXITVS008|
# |Hooverian Blur|Varvet 009|2018|
# |Varvet|VARVET009|
# |Stones Taro|After High|2019|
# |Scuffed|SCUFFED012|
# |Xanexx|Poem of Light|2018|
# |SCOPÁVIK|SPV002|
# |Qebo|Formulations|2019|
# |Numb Capsule|NC013|
# |Wahono|Prambanan / Mabad|2019|
# |DIVISI62|D6207|
# |Ivan Conti|Poison Fruit|2019|
# |Far Out|FARO208|
# |Hoover1|Hoover1|2019|
# |Hoover|HOOVER1|
# |Various Artists|Directors Cut 01|2019|
# |Voitax|VOIDC01|
# |AyGeeTee & Birdy Earns|Morphology|2019|
# |Seagrave|SR070|
# |Sune|Mimosa Kuriosa|2018|
# |Live Ones|LIVE004|
# |REQ|Tape Transport: 1994-2000|2019|
# |Seagrave|SR071|
# |Machine Woman|When a Machine Cries, You Get Petrol|2019|
# |Take Away Jazz|TAJR005|
# |Ed Longo & The Applied Arts Ensemble|The Other Fantasy|2019|
# |Early Sounds|EAS020|
# |Ohbliv|Soulphonic|2019|
# |Self-released|none|
# |Piezo|Gattomatto / Cala|2016|
# |Ansia|ANSIA001|
# |Christoph El’ Truento|Peace Maker Dub|2019|
# |Cosmic Compositions|CCO21|
# |log(m) & Laraaji|The Onrush of Eternity|2019|
# |Invisible, Inc.|INVINC21|
# |DJ Speedsick|Nothing Lasts|2019|
# |BANK|BNK019|
# |Last Jazz Club|Jazz Is… Instrumentals Vol. 1|2019|
# |Chopped Herring|CHINST05|
# |Mika Snickars|Mystery Of Reality|2018|
# |Good Morning Tapes|GMT10|
# |Piezo|Parrots|2018|
# |Ansia|ANSIA002|
# |Lee Gamble|In a Paraventral Scale|2019|
# |Hyperdub|HDB119D|
# |Hampshire & Foat|The Mage|2019|
# |Athens of the North|AOTN016|
# |Lapien|Brumal|2019|
# |Tikita|TIKITA009|
# |Nicola Cruz|Siku|2019|
# |ZZK|ZZK040|
# |Swarvy|Blends|2019|
# |Self-released|none|
# |Various Artists|Street Tracks White 001|2019|
# |W&O Street|STW001|
# |Solarize|Nachtwerk (1991-1998)|2019|
# |Bureau B|BB311|
# |Shcaa|An Ungrateful Death|2019|
# |R&S|RS1901|
# |Bendik Giske|Surrender|2019|
# |Smalltown Supersound|STS334|
# |Armless Kid|Choices|2019|
# |Vertv|VRTV005|
# |Various Artists|Applied Sociolinguistics|2019|
# |Kaer‘Uiks|KRX019|
# |Black Merlin|Kode|2019|
# |Die Orakel|ORKL12|
# |Glyn Hendry|Escape Club 99|2019|
# |Poly Kicks|POLY009|
# |Fixate|ReFIXes VOL. 1|2019|
# |Self-released|none|
# |Om Unit|Violet|2019|
# |Violet|VIOLET01D|
# |Mchy I Porosty|The Dead Pterodactyl|2019|
# |Kikimora Tapes|KMT016|
# |Various Artists|ANSIA003|2019|
# |Ansia|ANSIA003|
# |Ceephax Acid Crew|Acid Cask 1 Pandemonium|2018|
# |WéMè|WEME051|
# |Autechre|AE_LIVE|2019|
# |Warp|WARP360|
# |Antoni Maiovvi|The Ken Russell|2018|
# |OMNIDISC|OMD019|
# |Substance|Rise and Shine|2019|
# |Ostgut Ton|OTON115|
# |Andrés|D.ATLien|2018|
# |NDATL|NDATL021|
# |Golpe De Estado|Liquido|2019|
# |Discos Capablanca|DISCODIECISEIS|
# |JH1.FS3|Trials and Tribulations|2019|
# |Dais|DAIS126|
# |Various Artists / Jazz Is The Teacher|Funk Is The Preacher|2018|
# |Soul Jazz|SJR423|
# |Free Level|Blue Grass|2019|
# |Into The Light|ITL009|
# |Martina Lussi|Diffusion Is a Force|2019|
# |Latency|LTNC016|
# |Various Artists|Black Label Series 03|2019|
# |Banoffee Pies|BPBL03|
# |Unknown Artist|WASH#2|2018|
# |Delicate Wash|WASH#2|
# |De Gama|Funktastic|2018|
# |Samosa|SMS004|
# |Coppice Halifax|Etchings In Rust|2018|
# |Self-released|none|
# |Pablo’s Eye|Dark Matter|2019|
# |STROOM|STRLP022|
# |German Army|MOVE9|2018|
# |Fort Evil Fruit|FEF74|
# |Jigga|iliiiilii|2019|
# |Bedouin|BDN022|
# |Ami Shavit|Yom Kippur 1973|2019|
# |Sub Rosa|SRV456|
# |Jay Glass Dubs|Epitaph|2019|
# |Bokeh Versions|BKV023|
# |Various Artists|Casa Sports Vol.2|2018|
# |Casa Voyager|CSV04|
# |Cassettes For Kids & Tom Jarmey|UNIT01|2019|
# |Unit Two|UNIT01|
# |New World Music|Intellectual Thinking|2019|
# |Numero Group|NUM803|
# |Krikor|Building Arnold Schwarzenegger|2019|
# |Self-released|none|
# |Calibre|Break That|2018|
# |The Nothing Special|TNS027|
# |Joe Cleen|SBEDITZ004|2018|
# |SlothBoogie Editz|SBEDITZ004|
# |Lo Kindre|Chlorophytum|2019|
# |12th Isle|ISLE007|
# |Tsuruda|Internet Slaps Vol. 2|2019|
# |Self-released|none|
# |Villa Åbo|Carpet Proof of Daily Reports|2019|
# |iDEAL|iDEAL168|
# |Massimo Magrini|Vrachnas|2019|
# |Backwards|BWCD04|
# |Various Artists|Heroes II|2019|
# |Too Many Cars|TMCREC002|
# |DJ Fulltono|Before The Storm|2019|
# |Exit|EXIT080|
# |Tarjei Nygård|Lost in Lindos|2019|
# |ESP Institute|ESP073|
# |Our Lady Of The Flowers|Holiday In Thule|2019|
# |13|SPS1830|
# |DJ Fett Burger & Stiletti Ana|358 Men|2018|
# |Freakout Cult|CULT10|
# |Umwelt & Ryan James Ford|Untitled|2018|
# |Repitch|RPTCH09|
# |James Welsh|Hammers|2019|
# |Futureboogie|FBR063|
# |Kamikaze Space Programme & Eomac|ETXC004|2018|
# |Eotrax|ETXC004|
# |R.H.G.T.|Depersonalisation|2019|
# |Opal Tapes|OPAL137|
# |Kluentah|001|2018|
# |Zement|ZMNT001|
# |Gonçalo Penas|Ego De Espinhos|2019|
# |Subtext|SUB027|
# |JAK3|Earth Four: Moonlight Radiation|2019|
# |Origin Peoples|OPX26|
# |Selm|Kreise|2019|
# |Opal Tapes|OPAL138|
# |Various Artists|Sound Journal: Do​-​Nothing|2018|
# |Slow Editions|none|
# |Clive Tanaka|Unreliable Narrator|2018|
# |Tall Corn|CS9|
# |Headland|Young Blood / Witness|2018|
# |System|SYSTM024|
# |Siavash Amini & Matt Finney|Second Shift|2019|
# |Opal Tapes|OPAL139|
# |Various Artists|Vital Impetus|2019|
# |June|JUNE14|
# |Black Rain|Computer Soul|2019|
# |Blackest Ever Black|BLACKEST072|
# |Demian Licht & Eomac|ETXC003|2018|
# |Eotrax|ETXC003|
# |The Maghreban|Islands|2019|
# |Zoot|ZEP013|
# |Efdemin|New Atlantis|2019|
# |Ostgut Ton|OSTGUT45SINGLE1|
# |Stratis|New Face|2019|
# |Dark Entries|DE241|
# |Various Artists|Elsewhere CDXLIV|2019|
# |Crevette|CREV02|
# |Donna Trump|Donna Trump|2018|
# |Donna Trump|5R5LYFCKD15C065|
# |Pavel Milyakov|La Maison De La Mort|2019|
# |Berceuse Heroique|BH057|
# |Gallegos|Mad As Hell|2018|
# |Banoffee Pies|BP008|
# |Ill Considered|Ill Considered 6|2019|
# |Ill Considered|STACLP07|
# |Cassius Select|Slang|2018|
# |Self-released|none|
# |Beatrice Dillon|Selects /  Dissects|2018|
# |Rvng Intl.|RVNGNL53|
# |Automation|Comedown|2018|
# |The Healing Company|THC15|
# |Bugs Bunny|001|2018|
# |Tooney Lunes|TOONEYLUNES001|
# |Sias|May 1932 / Of Cotton|2019|
# |Jheri|JT7X12|
# |Seán Carpio & Eomac|ETXC002|2018|
# |Eotrax|ETXC002|
# |My Flower|Rea|2019|
# |Just This|JUSTTHIS025|
# |Jorge Velez|Roman Birds|2018|
# |Self-released|none|
# |NKISI|7 Directions|2019|
# |UIQ|UIQLP002|
# |Ill Considered|Ill Considered 5|2019|
# |Ill Considered|STACLP06|
# |Jay Mitta|Tatizo Pesa|2019|
# |Nyege Nyege Tapes|NNT010|
# |Luke Eargoggle|Stranger Destiny (1999-2009)|2018|
# |brokntoys|BT27CHR01|
# |Cruel Diagonals|Pulse of Indignation|2018|
# |Drawing Room|DR00032|
# |Christoph De Babalon|Hectic Shakes|2019|
# |Alter|ALT44|
# |Jesse Bru|That Feeling|2018|
# |Pulse Msc|PMSC006|
# |Hama|Houmeissa|2019|
# |Sahel Sounds|SS049|
# |Greg Ward|Stomping off from Greenwood|2019|
# |Greenleaf|GRE1069|
# |Bardar|The Golden Gate|2018|
# |Pinkman|PBD13.5|
# |Rude & Mean|High Praise Edits Vol III|2018|
# |XVI|HP003|
# |Nkisi|The Dark Orchestra|2018|
# |Arcola|ARC14|
# |Brian Marsella Trio|Outspoken: The Music Of The Legendary Hasaan|2018|
# |Tzadik|TZ4026|
# |Rabit|THE DOPE SHOW|2019|
# |Self-released|none|
# |cv313|Glass City Sessions|2019|
# |minimood|minimood017|
# |Dominique Duverger|KL05|2018|
# |Kavalanic Languages|KL05|
# |Belpaese|Belpaese 001|2018|
# |Belpaese Edits|BELP001|
# |Crotocosm|Setting The Scene For An Island Battle|2018|
# |No ‘Label’|RHD034CROTO|

# %% [markdown]
# # SQL DB Initialization

# %%
engine = create_engine("sqlite:///undergroundMusic.sqlite")
#engine = create_engine("mysql://root:invokes5gobletturtle@localhost:3306/sakila")
conn = engine.connect()

# %%
# Sets an object to utilize the default declarative base in SQL Alchemy
Base = declarative_base()

class Albums(Base):
    __tablename__ = 'Albums'
    id = Column("album_id", Integer, primary_key=True)
    url = Column(String(255))
    artist = Column(String(255))
    album = Column(String(255))
    year = Column(Integer)
    date = Column(Date)
    cover = Column(String(255))
    label = Column(String(255))
    catalog = Column(String(255))
    
class Genres(Base):
    __tablename__ = 'Genres'
    id = Column("genre_id", Integer, primary_key=True)
    name = Column(String(255))
    description = Column(String(8000))

class Album_Genres(Base):
    __tablename__ = 'Album_Genres'
    id = Column("album_genre_id", Integer, primary_key=True)
    album_id = Column(Integer, ForeignKey('Albums.album_id'))
    genre_id = Column(Integer, ForeignKey('Genres.genre_id'))

# %%
# Use this to clear out the db
# ----------------------------------
Base.metadata.drop_all(engine)

# ----------------------------------
# Create (if not already in existence) the tables associated with our classes.
Base.metadata.create_all(engine)

# %% [markdown]
# # Populate SQL DB

# %%
session = Session(bind=engine)

for entry in undergroundMusic:
    album = Albums(url = entry["url"], artist = entry["artist"], album = entry["album"], 
                   year = entry["year"], date = entry["date"], cover = entry["cover"], 
                   label = entry["label"], catalog = entry["catalog"])
    session.add(album)
    
    for item in entry["genres"]:
        exists = session.query(Genres.id).filter_by(name=item).scalar() is not None
        #if item exists in Genres db, skip
        if exists:
            pass
        #else, lookup wiki summary and add item to Genres table
        else:
            if item == "Album":
                summary = wikipedia.summary(item)
            elif item == "EP":
                summary = wikipedia.summary("Extended Play")
            elif item == "Various Artists" or item == "Compilation" or item == "Anthology":
                summary = wikipedia.summary("Compilation Album")
            elif item == "Leftfield":
                summary = wikipedia.summary("Progressive House")
            elif item == "Avantgarde":
                summary = wikipedia.summary("Avant-garde music")
            elif item == "Acid" or item == "Ghetto" or item == "Garage":
                summary = wikipedia.summary(item + " House")
            elif item == "Beats":
                summary = wikipedia.summary("Beat (music)")
            elif item == "Boogie":
                summary = wikipedia.summary("Boogie (genre)")
            elif item == "Remixes":
                summary = wikipedia.summary("Remix")
            elif item == "Dance Hall":
                summary = wikipedia.summary("Dancehall")
            elif item == "Live":
                summary = wikipedia.summary("Concert")
            elif item == "Uncategorized":
                summary = wikipedia.summary("Experimental Music")
            else:
                summary = wikipedia.summary(item + " music")
            genre = Genres(name = item, description = summary)
            session.add(genre)
            time.sleep(1)
            
    session.commit()

# %%
for entry in undergroundMusic:
    albumID = session.query(Albums.id).filter_by(url=entry["url"]).scalar()
    
    for genre in entry["genres"]:
        genreID = session.query(Genres.id).filter_by(name=genre).scalar()
        ids = Album_Genres(album_id = albumID, genre_id = genreID)
        session.add(ids)
        session.commit()

# %%
print("Database created.")
print(f"{len(undergroundMusic)} albums added.")
# Out:
# Database created.
# 600 albums added.
